# %%
# --- Installation ---
print("Installing required libraries...")
# !pip install -q tensorflow tensorflow_model_optimization scikit-learn matplotlib seaborn matplotlib mediapipe opencv-python tabulate
print("Installation complete.")
# Out:
# Installing required libraries...
# Installation complete.

# %%
# --- Standard Libraries ---
import os
import time
import timeit

# --- Scientific and Data Handling Libraries ---
import numpy as np
import pandas as pd

# --- Visualization Libraries ---
import matplotlib.pyplot as plt
import seaborn as sns

# --- Machine Learning Libraries ---
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# --- Deep Learning Libraries ---
import tensorflow as tf
import tensorflow_model_optimization as tfmot
import keras
from tensorflow.keras import layers, models, callbacks, regularizers, utils

# --- Computer Vision Library ---
import cv2

# --- Google Colab ---
from google.colab import drive

# --- Progress Bar ---
from tqdm.notebook import tqdm

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout,
    LSTM, TimeDistributed, Bidirectional,
    Conv1D, MaxPooling1D, SeparableConv1D, SeparableConv2D,
    Activation, Masking, Input, LayerNormalization
)
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, RMSprop

# %%
# --- Reproducibility ---
# Set a seed for random operations to ensure that results are consistent across runs.
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

print("\nLibraries imported and seed set for reproducibility.")
# Out:
# Libraries imported and seed set for reproducibility.

# %%
# --- Mount Google Drive ---
print("Mounting Google Drive...")
drive.mount('/content/drive')
# Out:
# Mounting Google Drive...
# Mounted at /content/drive

# %%
# --- Load Data (mediapipe features) ---
DATA_PATH = '/content/drive/MyDrive/major_project/features/'
X_path = os.path.join(DATA_PATH, 'X_original_increased_sampled_mixture_augmentation.npy')
y_path = os.path.join(DATA_PATH, 'y_original_increased_sampled_mixture_augmentation.npy')

print(f"\nLoading data from {DATA_PATH}...")
X = np.load(X_path)
y = np.load(y_path)

print(f"\nData loaded. X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Loading data from /content/drive/MyDrive/major_project/features/...
#
# Data loaded. X shape: (3960, 75, 177), y shape: (3960, 33)

# %%
# --- Split Data (70% Train, 20% Test, 10% Validation) ---
print("Splitting data into training, validation, and test sets...")

# First split: Separate 20% for the test set.
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, random_state=SEED, stratify=y
)

# Second split: Split the remaining data (80%) into training (70%) and validation (10%).
# The validation size relative to the temp set is 10 / (70 + 10) = 0.125
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.125, random_state=SEED, stratify=y_temp
)

print("\nData splitting complete.")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape:   {X_val.shape}, y_val shape:   {y_val.shape}")
print(f"X_test shape:  {X_test.shape}, y_test shape:  {y_test.shape}")

# For example, if:
# Class A has 100 samples
# Class B has 70 samples
# Class C has 90 samples
# Then the 70-10-20 split with stratify will give:
# Train: 70% of A, B, C
# Val: 10% of A, B, C
# Test: 20% of A, B, C
# Out:
# Splitting data into training, validation, and test sets...
#
# Data splitting complete.
# X_train shape: (2772, 75, 177), y_train shape: (2772, 33)
# X_val shape:   (396, 75, 177), y_val shape:   (396, 33)
# X_test shape:  (792, 75, 177), y_test shape:  (792, 33)

# %%
# --- load model ---
def create_stacked_bilstm_model(input_shape, num_classes, lstm_units=512, dropout_rate=0.6):
    inputs = Input(shape=input_shape)

    # TFLite-compatible BiLSTM
    x = Bidirectional(LSTM(
        lstm_units,
        return_sequences=False,
        activation='tanh',                  # TFLite-compatible
        recurrent_activation='sigmoid',     # Explicitly avoid CuDNN
        unroll=True,                        # Needed for some TFLite conversions
        use_bias=True
    ))(inputs)

    x = Dropout(dropout_rate)(x)
    x = BatchNormalization()(x)

    # Dense layers with L2 regularization
    x = Dense(lstm_units, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(dropout_rate)(x)
    x = BatchNormalization()(x)

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# --- Get Model Parameters ---
input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# --- Build and Compile ---
print(f"Building model with input shape: {input_shape} and {num_classes} classes.")
model = create_stacked_bilstm_model(input_shape, num_classes)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
model.summary()
# Out:
# Building model with input shape: (75, 177) and 33 classes.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 75, 177)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 1024)           │     2,826,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 33)             │        16,929 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,374,113 (12.87 MB)
#  Trainable params: 3,371,041 (12.86 MB)
#  Non-trainable params: 3,072 (12.00 KB)

# %%
# --- Define Callbacks ---
# Define the path for saving the best model using the .keras format
checkpoint_path = "/content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras"

# Stop training when validation loss doesn't improve for 10 epochs
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=15, restore_best_weights=True, verbose=1
)
# Save the best model based on validation accuracy
model_checkpoint = callbacks.ModelCheckpoint(
    filepath=checkpoint_path, monitor='val_accuracy', save_best_only=True, verbose=1
)
# Reduce learning rate when validation loss plateaus
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1
)

# %%
# --- Train the Model ---
print("\nStarting model training...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=200,  # A high number; EarlyStopping will find the optimal point
    batch_size=32,
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)
print("\nModel training complete.")

# --- Extract Best Epoch Based on Validation Accuracy ---
val_acc = history.history['val_accuracy']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
train_loss = history.history['loss']

best_epoch = np.argmax(val_acc)
print(f"\nBest Epoch: {best_epoch + 1}")
print(f"Train Accuracy   : {train_acc[best_epoch]*100:.2f}%")
print(f"Validation Accuracy: {val_acc[best_epoch]*100:.2f}%")
print(f"Train Loss       : {train_loss[best_epoch]:.4f}")
print(f"Validation Loss  : {val_loss[best_epoch]:.4f}")
# Out:
# Starting model training...
# Epoch 1/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.0362 - loss: 11.0180
# Epoch 1: val_accuracy improved from -inf to 0.08586, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 92s 561ms/step - accuracy: 0.0363 - loss: 11.0165 - val_accuracy: 0.0859 - val_loss: 10.0466 - learning_rate: 1.0000e-04
# Epoch 2/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0596 - loss: 10.4531
# Epoch 2: val_accuracy improved from 0.08586 to 0.15657, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.0599 - loss: 10.4507 - val_accuracy: 0.1566 - val_loss: 9.5786 - learning_rate: 1.0000e-04
# Epoch 3/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0979 - loss: 9.9996
# Epoch 3: val_accuracy improved from 0.15657 to 0.16162, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.0981 - loss: 9.9969 - val_accuracy: 0.1616 - val_loss: 9.0909 - learning_rate: 1.0000e-04
# Epoch 4/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1192 - loss: 9.5250
# Epoch 4: val_accuracy improved from 0.16162 to 0.17677, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.1193 - loss: 9.5238 - val_accuracy: 0.1768 - val_loss: 8.7029 - learning_rate: 1.0000e-04
# Epoch 5/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1485 - loss: 9.0944
# Epoch 5: val_accuracy improved from 0.17677 to 0.26010, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.1488 - loss: 9.0926 - val_accuracy: 0.2601 - val_loss: 8.2374 - learning_rate: 1.0000e-04
# Epoch 6/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1878 - loss: 8.7266
# Epoch 6: val_accuracy improved from 0.26010 to 0.30051, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.1879 - loss: 8.7255 - val_accuracy: 0.3005 - val_loss: 7.8680 - learning_rate: 1.0000e-04
# Epoch 7/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2211 - loss: 8.3676
# Epoch 7: val_accuracy improved from 0.30051 to 0.36111, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.2211 - loss: 8.3670 - val_accuracy: 0.3611 - val_loss: 7.5583 - learning_rate: 1.0000e-04
# Epoch 8/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2808 - loss: 7.9381
# Epoch 8: val_accuracy did not improve from 0.36111
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.2807 - loss: 7.9375 - val_accuracy: 0.3611 - val_loss: 7.3172 - learning_rate: 1.0000e-04
# Epoch 9/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2717 - loss: 7.6637
# Epoch 9: val_accuracy improved from 0.36111 to 0.43434, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.2718 - loss: 7.6630 - val_accuracy: 0.4343 - val_loss: 6.9550 - learning_rate: 1.0000e-04
# Epoch 10/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3190 - loss: 7.3421
# Epoch 10: val_accuracy did not improve from 0.43434
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.3190 - loss: 7.3416 - val_accuracy: 0.4242 - val_loss: 6.7266 - learning_rate: 1.0000e-04
# Epoch 11/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3410 - loss: 7.0566
# Epoch 11: val_accuracy did not improve from 0.43434
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.3410 - loss: 7.0563 - val_accuracy: 0.3838 - val_loss: 6.6560 - learning_rate: 1.0000e-04
# Epoch 12/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3778 - loss: 6.7759
# Epoch 12: val_accuracy improved from 0.43434 to 0.51010, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.3776 - loss: 6.7755 - val_accuracy: 0.5101 - val_loss: 6.1830 - learning_rate: 1.0000e-04
# Epoch 13/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3893 - loss: 6.5274
# Epoch 13: val_accuracy did not improve from 0.51010
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.3892 - loss: 6.5270 - val_accuracy: 0.4773 - val_loss: 5.9742 - learning_rate: 1.0000e-04
# Epoch 14/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4093 - loss: 6.2295
# Epoch 14: val_accuracy improved from 0.51010 to 0.52525, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4094 - loss: 6.2286 - val_accuracy: 0.5253 - val_loss: 5.7308 - learning_rate: 1.0000e-04
# Epoch 15/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4674 - loss: 5.9647
# Epoch 15: val_accuracy improved from 0.52525 to 0.56061, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.4675 - loss: 5.9639 - val_accuracy: 0.5606 - val_loss: 5.5123 - learning_rate: 1.0000e-04
# Epoch 16/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4747 - loss: 5.7411
# Epoch 16: val_accuracy did not improve from 0.56061
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.4747 - loss: 5.7396 - val_accuracy: 0.5556 - val_loss: 5.3456 - learning_rate: 1.0000e-04
# Epoch 17/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4869 - loss: 5.5549
# Epoch 17: val_accuracy improved from 0.56061 to 0.60354, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.4871 - loss: 5.5534 - val_accuracy: 0.6035 - val_loss: 5.0800 - learning_rate: 1.0000e-04
# Epoch 18/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5180 - loss: 5.3015
# Epoch 18: val_accuracy did not improve from 0.60354
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5179 - loss: 5.3005 - val_accuracy: 0.5202 - val_loss: 5.1074 - learning_rate: 1.0000e-04
# Epoch 19/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5596 - loss: 5.0144
# Epoch 19: val_accuracy did not improve from 0.60354
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.5597 - loss: 5.0139 - val_accuracy: 0.5859 - val_loss: 4.8025 - learning_rate: 1.0000e-04
# Epoch 20/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6014 - loss: 4.7745
# Epoch 20: val_accuracy did not improve from 0.60354
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.6011 - loss: 4.7746 - val_accuracy: 0.5682 - val_loss: 4.7284 - learning_rate: 1.0000e-04
# Epoch 21/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5849 - loss: 4.6130
# Epoch 21: val_accuracy improved from 0.60354 to 0.64646, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5854 - loss: 4.6115 - val_accuracy: 0.6465 - val_loss: 4.3620 - learning_rate: 1.0000e-04
# Epoch 22/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6216 - loss: 4.3755
# Epoch 22: val_accuracy improved from 0.64646 to 0.67677, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.6217 - loss: 4.3752 - val_accuracy: 0.6768 - val_loss: 4.1497 - learning_rate: 1.0000e-04
# Epoch 23/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6706 - loss: 4.1201
# Epoch 23: val_accuracy did not improve from 0.67677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6704 - loss: 4.1202 - val_accuracy: 0.6237 - val_loss: 4.1305 - learning_rate: 1.0000e-04
# Epoch 24/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6726 - loss: 4.0112
# Epoch 24: val_accuracy improved from 0.67677 to 0.73232, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.6727 - loss: 4.0103 - val_accuracy: 0.7323 - val_loss: 3.7474 - learning_rate: 1.0000e-04
# Epoch 25/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7065 - loss: 3.7654
# Epoch 25: val_accuracy did not improve from 0.73232
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7064 - loss: 3.7654 - val_accuracy: 0.6818 - val_loss: 3.7122 - learning_rate: 1.0000e-04
# Epoch 26/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7392 - loss: 3.5761
# Epoch 26: val_accuracy improved from 0.73232 to 0.75505, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.7391 - loss: 3.5760 - val_accuracy: 0.7551 - val_loss: 3.4465 - learning_rate: 1.0000e-04
# Epoch 27/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7444 - loss: 3.4183
# Epoch 27: val_accuracy did not improve from 0.75505
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7444 - loss: 3.4182 - val_accuracy: 0.7551 - val_loss: 3.2548 - learning_rate: 1.0000e-04
# Epoch 28/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7618 - loss: 3.2770
# Epoch 28: val_accuracy did not improve from 0.75505
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.7615 - loss: 3.2768 - val_accuracy: 0.7348 - val_loss: 3.2516 - learning_rate: 1.0000e-04
# Epoch 29/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7659 - loss: 3.1574
# Epoch 29: val_accuracy improved from 0.75505 to 0.76515, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.7659 - loss: 3.1571 - val_accuracy: 0.7652 - val_loss: 3.1418 - learning_rate: 1.0000e-04
# Epoch 30/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8021 - loss: 2.9567
# Epoch 30: val_accuracy did not improve from 0.76515
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8021 - loss: 2.9564 - val_accuracy: 0.7348 - val_loss: 3.0583 - learning_rate: 1.0000e-04
# Epoch 31/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7894 - loss: 2.8580
# Epoch 31: val_accuracy did not improve from 0.76515
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7896 - loss: 2.8577 - val_accuracy: 0.7121 - val_loss: 3.1138 - learning_rate: 1.0000e-04
# Epoch 32/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7752 - loss: 2.8436
# Epoch 32: val_accuracy improved from 0.76515 to 0.79545, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.7755 - loss: 2.8417 - val_accuracy: 0.7955 - val_loss: 2.7214 - learning_rate: 1.0000e-04
# Epoch 33/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8457 - loss: 2.5389
# Epoch 33: val_accuracy did not improve from 0.79545
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8456 - loss: 2.5389 - val_accuracy: 0.7879 - val_loss: 2.6657 - learning_rate: 1.0000e-04
# Epoch 34/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8367 - loss: 2.4441
# Epoch 34: val_accuracy did not improve from 0.79545
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8367 - loss: 2.4435 - val_accuracy: 0.7247 - val_loss: 2.7168 - learning_rate: 1.0000e-04
# Epoch 35/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8370 - loss: 2.3484
# Epoch 35: val_accuracy improved from 0.79545 to 0.80051, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8370 - loss: 2.3485 - val_accuracy: 0.8005 - val_loss: 2.4254 - learning_rate: 1.0000e-04
# Epoch 36/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8412 - loss: 2.2557
# Epoch 36: val_accuracy improved from 0.80051 to 0.82323, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8410 - loss: 2.2559 - val_accuracy: 0.8232 - val_loss: 2.3264 - learning_rate: 1.0000e-04
# Epoch 37/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8662 - loss: 2.1048
# Epoch 37: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8662 - loss: 2.1047 - val_accuracy: 0.7828 - val_loss: 2.2884 - learning_rate: 1.0000e-04
# Epoch 38/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8708 - loss: 2.0092
# Epoch 38: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8708 - loss: 2.0090 - val_accuracy: 0.8081 - val_loss: 2.1353 - learning_rate: 1.0000e-04
# Epoch 39/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8764 - loss: 1.9425
# Epoch 39: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8761 - loss: 1.9428 - val_accuracy: 0.7955 - val_loss: 2.1849 - learning_rate: 1.0000e-04
# Epoch 40/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8786 - loss: 1.8508
# Epoch 40: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8786 - loss: 1.8505 - val_accuracy: 0.7475 - val_loss: 2.1291 - learning_rate: 1.0000e-04
# Epoch 41/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8735 - loss: 1.7697
# Epoch 41: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8735 - loss: 1.7695 - val_accuracy: 0.7399 - val_loss: 2.2269 - learning_rate: 1.0000e-04
# Epoch 42/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8943 - loss: 1.6839
# Epoch 42: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8943 - loss: 1.6836 - val_accuracy: 0.7980 - val_loss: 1.9744 - learning_rate: 1.0000e-04
# Epoch 43/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9011 - loss: 1.5716
# Epoch 43: val_accuracy did not improve from 0.82323
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9010 - loss: 1.5717 - val_accuracy: 0.8157 - val_loss: 1.8507 - learning_rate: 1.0000e-04
# Epoch 44/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9040 - loss: 1.4991
# Epoch 44: val_accuracy improved from 0.82323 to 0.83838, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9039 - loss: 1.4992 - val_accuracy: 0.8384 - val_loss: 1.7354 - learning_rate: 1.0000e-04
# Epoch 45/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9210 - loss: 1.3873
# Epoch 45: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9210 - loss: 1.3872 - val_accuracy: 0.8207 - val_loss: 1.7168 - learning_rate: 1.0000e-04
# Epoch 46/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9072 - loss: 1.3678
# Epoch 46: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9072 - loss: 1.3678 - val_accuracy: 0.7727 - val_loss: 1.8022 - learning_rate: 1.0000e-04
# Epoch 47/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9193 - loss: 1.3064
# Epoch 47: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9191 - loss: 1.3065 - val_accuracy: 0.8333 - val_loss: 1.4935 - learning_rate: 1.0000e-04
# Epoch 48/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9122 - loss: 1.2538
# Epoch 48: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9122 - loss: 1.2539 - val_accuracy: 0.8308 - val_loss: 1.5135 - learning_rate: 1.0000e-04
# Epoch 49/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8961 - loss: 1.2311
# Epoch 49: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8963 - loss: 1.2307 - val_accuracy: 0.8030 - val_loss: 1.6041 - learning_rate: 1.0000e-04
# Epoch 50/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9172 - loss: 1.1475
# Epoch 50: val_accuracy improved from 0.83838 to 0.87374, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9173 - loss: 1.1473 - val_accuracy: 0.8737 - val_loss: 1.3185 - learning_rate: 1.0000e-04
# Epoch 51/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9330 - loss: 1.0559
# Epoch 51: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9329 - loss: 1.0561 - val_accuracy: 0.8434 - val_loss: 1.3383 - learning_rate: 1.0000e-04
# Epoch 52/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9392 - loss: 1.0012
# Epoch 52: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9392 - loss: 1.0014 - val_accuracy: 0.8561 - val_loss: 1.2745 - learning_rate: 1.0000e-04
# Epoch 53/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9413 - loss: 0.9363
# Epoch 53: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9412 - loss: 0.9364 - val_accuracy: 0.8359 - val_loss: 1.3132 - learning_rate: 1.0000e-04
# Epoch 54/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9235 - loss: 0.9748
# Epoch 54: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9233 - loss: 0.9753 - val_accuracy: 0.8258 - val_loss: 1.3196 - learning_rate: 1.0000e-04
# Epoch 55/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9225 - loss: 0.9314
# Epoch 55: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9226 - loss: 0.9311 - val_accuracy: 0.8384 - val_loss: 1.2262 - learning_rate: 1.0000e-04
# Epoch 56/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9425 - loss: 0.8323
# Epoch 56: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9424 - loss: 0.8324 - val_accuracy: 0.8434 - val_loss: 1.2092 - learning_rate: 1.0000e-04
# Epoch 57/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9382 - loss: 0.8120
# Epoch 57: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9381 - loss: 0.8122 - val_accuracy: 0.8409 - val_loss: 1.1299 - learning_rate: 1.0000e-04
# Epoch 58/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9250 - loss: 0.8204
# Epoch 58: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9250 - loss: 0.8205 - val_accuracy: 0.8485 - val_loss: 1.0912 - learning_rate: 1.0000e-04
# Epoch 59/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9446 - loss: 0.7430
# Epoch 59: val_accuracy did not improve from 0.87374
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9444 - loss: 0.7437 - val_accuracy: 0.7702 - val_loss: 1.3888 - learning_rate: 1.0000e-04
# Epoch 60/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9042 - loss: 0.8929
# Epoch 60: val_accuracy improved from 0.87374 to 0.88131, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9045 - loss: 0.8917 - val_accuracy: 0.8813 - val_loss: 0.9683 - learning_rate: 1.0000e-04
# Epoch 61/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9601 - loss: 0.6497
# Epoch 61: val_accuracy did not improve from 0.88131
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9600 - loss: 0.6499 - val_accuracy: 0.8384 - val_loss: 1.0341 - learning_rate: 1.0000e-04
# Epoch 62/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9517 - loss: 0.6508
# Epoch 62: val_accuracy improved from 0.88131 to 0.88384, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9517 - loss: 0.6508 - val_accuracy: 0.8838 - val_loss: 0.9147 - learning_rate: 1.0000e-04
# Epoch 63/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9689 - loss: 0.5861
# Epoch 63: val_accuracy did not improve from 0.88384
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9688 - loss: 0.5864 - val_accuracy: 0.8283 - val_loss: 1.0441 - learning_rate: 1.0000e-04
# Epoch 64/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9522 - loss: 0.6212
# Epoch 64: val_accuracy did not improve from 0.88384
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9522 - loss: 0.6210 - val_accuracy: 0.8763 - val_loss: 0.8798 - learning_rate: 1.0000e-04
# Epoch 65/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9619 - loss: 0.5606
# Epoch 65: val_accuracy did not improve from 0.88384
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9619 - loss: 0.5607 - val_accuracy: 0.8586 - val_loss: 0.9544 - learning_rate: 1.0000e-04
# Epoch 66/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9430 - loss: 0.6071
# Epoch 66: val_accuracy did not improve from 0.88384
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9430 - loss: 0.6069 - val_accuracy: 0.8485 - val_loss: 0.9160 - learning_rate: 1.0000e-04
# Epoch 67/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9450 - loss: 0.5864
# Epoch 67: val_accuracy did not improve from 0.88384
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9449 - loss: 0.5863 - val_accuracy: 0.8712 - val_loss: 0.8676 - learning_rate: 1.0000e-04
# Epoch 68/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9537 - loss: 0.5226
# Epoch 68: val_accuracy improved from 0.88384 to 0.89141, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9538 - loss: 0.5225 - val_accuracy: 0.8914 - val_loss: 0.7927 - learning_rate: 1.0000e-04
# Epoch 69/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9740 - loss: 0.4656
# Epoch 69: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9737 - loss: 0.4664 - val_accuracy: 0.8308 - val_loss: 1.0091 - learning_rate: 1.0000e-04
# Epoch 70/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9429 - loss: 0.5204
# Epoch 70: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9430 - loss: 0.5202 - val_accuracy: 0.8207 - val_loss: 0.9734 - learning_rate: 1.0000e-04
# Epoch 71/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9455 - loss: 0.5018
# Epoch 71: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9456 - loss: 0.5017 - val_accuracy: 0.8838 - val_loss: 0.7846 - learning_rate: 1.0000e-04
# Epoch 72/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9665 - loss: 0.4434
# Epoch 72: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9664 - loss: 0.4434 - val_accuracy: 0.8434 - val_loss: 0.9701 - learning_rate: 1.0000e-04
# Epoch 73/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9605 - loss: 0.4418
# Epoch 73: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9605 - loss: 0.4416 - val_accuracy: 0.8662 - val_loss: 0.8240 - learning_rate: 1.0000e-04
# Epoch 74/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9719 - loss: 0.3982
# Epoch 74: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9719 - loss: 0.3984 - val_accuracy: 0.8485 - val_loss: 0.9136 - learning_rate: 1.0000e-04
# Epoch 75/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9570 - loss: 0.4111
# Epoch 75: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9571 - loss: 0.4109 - val_accuracy: 0.8788 - val_loss: 0.6765 - learning_rate: 1.0000e-04
# Epoch 76/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9828 - loss: 0.3438
# Epoch 76: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9827 - loss: 0.3439 - val_accuracy: 0.8662 - val_loss: 0.7125 - learning_rate: 1.0000e-04
# Epoch 77/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9477 - loss: 0.4280
# Epoch 77: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9478 - loss: 0.4277 - val_accuracy: 0.8485 - val_loss: 0.8767 - learning_rate: 1.0000e-04
# Epoch 78/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9582 - loss: 0.4064
# Epoch 78: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9580 - loss: 0.4066 - val_accuracy: 0.8737 - val_loss: 0.7324 - learning_rate: 1.0000e-04
# Epoch 79/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9623 - loss: 0.3931
# Epoch 79: val_accuracy did not improve from 0.89141
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9624 - loss: 0.3929 - val_accuracy: 0.8788 - val_loss: 0.7307 - learning_rate: 1.0000e-04
# Epoch 80/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9774 - loss: 0.3206
# Epoch 80: val_accuracy did not improve from 0.89141
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9774 - loss: 0.3206 - val_accuracy: 0.8763 - val_loss: 0.7006 - learning_rate: 1.0000e-04
# Epoch 81/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9806 - loss: 0.3042
# Epoch 81: val_accuracy improved from 0.89141 to 0.90152, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9807 - loss: 0.3040 - val_accuracy: 0.9015 - val_loss: 0.5984 - learning_rate: 5.0000e-05
# Epoch 82/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9925 - loss: 0.2616
# Epoch 82: val_accuracy improved from 0.90152 to 0.91162, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9925 - loss: 0.2615 - val_accuracy: 0.9116 - val_loss: 0.5559 - learning_rate: 5.0000e-05
# Epoch 83/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9924 - loss: 0.2481
# Epoch 83: val_accuracy did not improve from 0.91162
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9924 - loss: 0.2482 - val_accuracy: 0.9091 - val_loss: 0.5383 - learning_rate: 5.0000e-05
# Epoch 84/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9938 - loss: 0.2384
# Epoch 84: val_accuracy did not improve from 0.91162
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9938 - loss: 0.2384 - val_accuracy: 0.9091 - val_loss: 0.5180 - learning_rate: 5.0000e-05
# Epoch 85/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9956 - loss: 0.2296
# Epoch 85: val_accuracy did not improve from 0.91162
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9956 - loss: 0.2296 - val_accuracy: 0.9091 - val_loss: 0.5264 - learning_rate: 5.0000e-05
# Epoch 86/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9960 - loss: 0.2230
# Epoch 86: val_accuracy improved from 0.91162 to 0.92424, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9960 - loss: 0.2231 - val_accuracy: 0.9242 - val_loss: 0.5110 - learning_rate: 5.0000e-05
# Epoch 87/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9970 - loss: 0.2126
# Epoch 87: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9969 - loss: 0.2127 - val_accuracy: 0.8939 - val_loss: 0.6030 - learning_rate: 5.0000e-05
# Epoch 88/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9908 - loss: 0.2286
# Epoch 88: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9908 - loss: 0.2287 - val_accuracy: 0.8813 - val_loss: 0.6862 - learning_rate: 5.0000e-05
# Epoch 89/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9841 - loss: 0.2371
# Epoch 89: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9840 - loss: 0.2374 - val_accuracy: 0.8914 - val_loss: 0.5808 - learning_rate: 5.0000e-05
# Epoch 90/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9834 - loss: 0.2397
# Epoch 90: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9835 - loss: 0.2395 - val_accuracy: 0.9167 - val_loss: 0.5446 - learning_rate: 5.0000e-05
# Epoch 91/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9969 - loss: 0.2004
# Epoch 91: val_accuracy did not improve from 0.92424
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9969 - loss: 0.2004 - val_accuracy: 0.9141 - val_loss: 0.5142 - learning_rate: 5.0000e-05
# Epoch 92/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9962 - loss: 0.1901
# Epoch 92: val_accuracy improved from 0.92424 to 0.92677, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/bilstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9962 - loss: 0.1901 - val_accuracy: 0.9268 - val_loss: 0.4897 - learning_rate: 2.5000e-05
# Epoch 93/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9991 - loss: 0.1825
# Epoch 93: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9991 - loss: 0.1825 - val_accuracy: 0.9268 - val_loss: 0.4812 - learning_rate: 2.5000e-05
# Epoch 94/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9982 - loss: 0.1803
# Epoch 94: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9982 - loss: 0.1803 - val_accuracy: 0.9167 - val_loss: 0.4867 - learning_rate: 2.5000e-05
# Epoch 95/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9979 - loss: 0.1745
# Epoch 95: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9979 - loss: 0.1745 - val_accuracy: 0.9141 - val_loss: 0.4913 - learning_rate: 2.5000e-05
# Epoch 96/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9969 - loss: 0.1731
# Epoch 96: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9969 - loss: 0.1731 - val_accuracy: 0.9268 - val_loss: 0.4579 - learning_rate: 2.5000e-05
# Epoch 97/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9977 - loss: 0.1674
# Epoch 97: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9977 - loss: 0.1675 - val_accuracy: 0.9192 - val_loss: 0.4559 - learning_rate: 2.5000e-05
# Epoch 98/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9976 - loss: 0.1625
# Epoch 98: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9976 - loss: 0.1625 - val_accuracy: 0.9167 - val_loss: 0.4572 - learning_rate: 2.5000e-05
# Epoch 99/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9977 - loss: 0.1597
# Epoch 99: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9977 - loss: 0.1597 - val_accuracy: 0.9217 - val_loss: 0.4631 - learning_rate: 2.5000e-05
# Epoch 100/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9989 - loss: 0.1558
# Epoch 100: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9989 - loss: 0.1558 - val_accuracy: 0.9192 - val_loss: 0.4656 - learning_rate: 2.5000e-05
# Epoch 101/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9976 - loss: 0.1529
# Epoch 101: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9976 - loss: 0.1529 - val_accuracy: 0.9167 - val_loss: 0.4676 - learning_rate: 2.5000e-05
# Epoch 102/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9980 - loss: 0.1490
# Epoch 102: val_accuracy did not improve from 0.92677
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9980 - loss: 0.1490 - val_accuracy: 0.9192 - val_loss: 0.4709 - learning_rate: 2.5000e-05
# Epoch 103/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9994 - loss: 0.1455
# Epoch 103: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9994 - loss: 0.1455 - val_accuracy: 0.9217 - val_loss: 0.4571 - learning_rate: 1.2500e-05
# Epoch 104/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9985 - loss: 0.1443
# Epoch 104: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9985 - loss: 0.1443 - val_accuracy: 0.9217 - val_loss: 0.4489 - learning_rate: 1.2500e-05
# Epoch 105/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9981 - loss: 0.1429
# Epoch 105: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9981 - loss: 0.1429 - val_accuracy: 0.9217 - val_loss: 0.4462 - learning_rate: 1.2500e-05
# Epoch 106/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9998 - loss: 0.1390
# Epoch 106: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9998 - loss: 0.1391 - val_accuracy: 0.9242 - val_loss: 0.4472 - learning_rate: 1.2500e-05
# Epoch 107/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1363
# Epoch 107: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.1363 - val_accuracy: 0.9141 - val_loss: 0.4485 - learning_rate: 1.2500e-05
# Epoch 108/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9992 - loss: 0.1351
# Epoch 108: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9991 - loss: 0.1351 - val_accuracy: 0.9192 - val_loss: 0.4578 - learning_rate: 1.2500e-05
# Epoch 109/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1324
# Epoch 109: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 1.0000 - loss: 0.1324 - val_accuracy: 0.9242 - val_loss: 0.4603 - learning_rate: 1.2500e-05
# Epoch 110/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9997 - loss: 0.1306
# Epoch 110: val_accuracy did not improve from 0.92677
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9997 - loss: 0.1306 - val_accuracy: 0.9217 - val_loss: 0.4605 - learning_rate: 1.2500e-05
# Epoch 111/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9998 - loss: 0.1285
# Epoch 111: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9997 - loss: 0.1285 - val_accuracy: 0.9217 - val_loss: 0.4705 - learning_rate: 6.2500e-06
# Epoch 112/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9999 - loss: 0.1280
# Epoch 112: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9999 - loss: 0.1281 - val_accuracy: 0.9217 - val_loss: 0.4657 - learning_rate: 6.2500e-06
# Epoch 113/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9989 - loss: 0.1273
# Epoch 113: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9989 - loss: 0.1273 - val_accuracy: 0.9192 - val_loss: 0.4660 - learning_rate: 6.2500e-06
# Epoch 114/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9999 - loss: 0.1277
# Epoch 114: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9999 - loss: 0.1277 - val_accuracy: 0.9167 - val_loss: 0.4613 - learning_rate: 6.2500e-06
# Epoch 115/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9991 - loss: 0.1246
# Epoch 115: val_accuracy did not improve from 0.92677
#
# Epoch 115: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9991 - loss: 0.1246 - val_accuracy: 0.9167 - val_loss: 0.4662 - learning_rate: 6.2500e-06
# Epoch 116/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9984 - loss: 0.1257
# Epoch 116: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9984 - loss: 0.1257 - val_accuracy: 0.9141 - val_loss: 0.4616 - learning_rate: 3.1250e-06
# Epoch 117/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9992 - loss: 0.1246
# Epoch 117: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9992 - loss: 0.1246 - val_accuracy: 0.9167 - val_loss: 0.4602 - learning_rate: 3.1250e-06
# Epoch 118/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9990 - loss: 0.1234
# Epoch 118: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9990 - loss: 0.1234 - val_accuracy: 0.9167 - val_loss: 0.4594 - learning_rate: 3.1250e-06
# Epoch 119/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9998 - loss: 0.1219
# Epoch 119: val_accuracy did not improve from 0.92677
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9998 - loss: 0.1219 - val_accuracy: 0.9192 - val_loss: 0.4505 - learning_rate: 3.1250e-06
# Epoch 120/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9995 - loss: 0.1218
# Epoch 120: val_accuracy did not improve from 0.92677
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9995 - loss: 0.1218 - val_accuracy: 0.9167 - val_loss: 0.4521 - learning_rate: 3.1250e-06
# Epoch 120: early stopping
# Restoring model weights from the end of the best epoch: 105.
#
# Model training complete.
#
# Best Epoch: 92
# Train Accuracy   : 99.57%
# Validation Accuracy: 92.68%
# Train Loss       : 0.1891
# Validation Loss  : 0.4897

# %%
# --- Load Best Model ---
# The best model was saved during training by the ModelCheckpoint callback.
print("\nLoading the best model for final evaluation...")
best_model = models.load_model(
    checkpoint_path,
)

# --- Evaluate ---
print("Evaluating model on the test set...")
loss, accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Loading the best model for final evaluation...
# Evaluating model on the test set...
#
# Test Loss: 0.4448
# Test Accuracy: 93.06%

# %%
# --- Path to save metrics ---
import os
from datetime import datetime

# Set output directory in Google Drive
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
output_dir = f"/content/drive/MyDrive/major_project/metrics/bilstm_mixed_training_metrics/Run_{timestamp}"
# /content/drive/MyDrive/major_project/models/checkpoint_models/original_increased_sampled_mixture_augmentation_best_model.keras
os.makedirs(output_dir, exist_ok=True)

# %%
# --- Visualization ---

# 'history', 'best_model', 'X_test', and 'y_test' are already defined.

# ==============================================================================
# IMPORTANT: class names
# ==============================================================================
class_names = [
    'Afternoon', 'Apple', 'April', 'August', 'Banana', 'Day', 'December',
    'Evening', 'February', 'Friday', 'Grapes', 'January', 'July', 'June',
    'March', 'May', 'Monday', 'Morning', 'Night', 'November', 'October',
    'Orange', 'Rainy', 'Saturday', 'September', 'Summer', 'Sunday',
    'Thursday', 'Tuesday', 'Valencia_Orange', 'Watermelon', 'Wednesday', 'Winter'
]


# --- 1. Plot Training History (Accuracy & Loss Curves) ---
print("Displaying model training history...")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle('Model Training History', fontsize=16)

# Accuracy
ax1.plot(history.history['accuracy'], label='Train Accuracy', color='blue', marker='o')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', marker='o')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

# Loss
ax2.plot(history.history['loss'], label='Train Loss', color='blue', marker='o')
ax2.plot(history.history['val_loss'], label='Validation Loss', color='orange', marker='o')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)
plt.savefig(f"{output_dir}/training_history.png", dpi=1000)
plt.show()


# --- 2. Generate Predictions and Detailed Report ---
print("\nGenerating predictions and performance metrics...")
y_pred_probs = best_model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print("\n" + "="*60)
print("           Classification Report")
print("="*60)
report_dict = classification_report(y_true_classes, y_pred_classes,
                                    target_names=class_names, output_dict=True)
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))


# --- 3. Visualize Per-Class Performance ---

# Confusion Matrix
print("\nDisplaying Confusion Matrix...")
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(20, 18))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix', fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig(f"{output_dir}/confusion_matrix.png", dpi=1000)
plt.show()

# F1-Score Bar Chart
print("\nDisplaying F1-Scores for each class...")
report_df = pd.DataFrame(report_dict).transpose()
report_df = report_df.drop(['accuracy', 'macro avg', 'weighted avg'])

plt.figure(figsize=(18, 10))
sns.barplot(data=report_df, x=report_df.index, y='f1-score',
            hue=report_df.index, palette='viridis', legend=False)
plt.title('F1-Score per Class', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(f"{output_dir}/f1_scores.png", dpi=1000)
plt.show()


# --- 4. Display Overall Model Metrics Separately (NEW) ---
print("\n" + "="*60)
print("         Overall Model Performance Summary")
print("="*60)

# Extracting the overall metrics from the report dictionary
overall_accuracy = report_dict['accuracy']
weighted_avg_metrics = report_dict['weighted avg']
overall_precision = weighted_avg_metrics['precision']
overall_recall = weighted_avg_metrics['recall']
overall_f1 = weighted_avg_metrics['f1-score']

print(f"✅ Overall Accuracy:           {overall_accuracy:.4f}")
print(f"🎯 Overall Precision (Weighted): {overall_precision:.4f}")
print(f"🎯 Overall Recall (Weighted):    {overall_recall:.4f}")
print(f"🎯 Overall F1-Score (Weighted):  {overall_f1:.4f}")
print("="*60)
# Out:
# Displaying model training history...
# Generating predictions and performance metrics...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 441ms/step
#
# ============================================================
#            Classification Report
# ============================================================
#                  precision    recall  f1-score   support
#
#       Afternoon       0.96      1.00      0.98        24
#           Apple       0.92      0.96      0.94        24
#           April       0.91      0.88      0.89        24
#          August       0.96      1.00      0.98        24
#          Banana       0.92      1.00      0.96        24
#             Day       1.00      1.00      1.00        24
#        December       1.00      0.88      0.93        24
#         Evening       0.96      0.92      0.94        24
#        February       1.00      0.96      0.98        24
#          Friday       0.96      0.96      0.96        24
#          Grapes       0.85      0.92      0.88        24
#         January       0.88      0.92      0.90        24
#            July       0.96      1.00      0.98        24
#            June       0.86      0.79      0.83        24
#           March       0.83      0.79      0.81        24
#             May       0.88      0.92      0.90        24
#          Monday       0.96      0.92      0.94        24
#         Morning       0.96      0.96      0.96        24
#           Night       1.00      0.92      0.96        24
#        November       0.95      0.88      0.91        24
#         October       0.92      1.00      0.96        24
#          Orange       0.95      0.88      0.91        24
#           Rainy       1.00      0.92      0.96        24
#        Saturday       0.95      0.79      0.86        24
#       September       0.96      0.96      0.96        24
#          Summer       0.92      0.92      0.92        24
#          Sunday       0.92      1.00      0.96        24
#        Thursday       0.89      1.00      0.94        24
#         Tuesday       0.86      1.00      0.92        24
# Valencia_Orange       0.92      0.96      0.94        24
#      Watermelon       0.91      0.88      0.89        24
#       Wednesday       0.92      0.92      0.92        24
#          Winter       0.92      0.96      0.94        24
#
#        accuracy                           0.93       792
#       macro avg       0.93      0.93      0.93       792
#    weighted avg       0.93      0.93      0.93       792
#
#
# Displaying Confusion Matrix...
# Displaying F1-Scores for each class...
# ============================================================
#          Overall Model Performance Summary
# ============================================================
# ✅ Overall Accuracy:           0.9306
# 🎯 Overall Precision (Weighted): 0.9321
# 🎯 Overall Recall (Weighted):    0.9306
# 🎯 Overall F1-Score (Weighted):  0.9301
# ============================================================

# %%
# --- Save Classification Report to Files ---

# Save the classification report DataFrame to a CSV file for easy spreadsheet access.
report_df.to_csv(f"{output_dir}/classification_report.csv")

# Save the classification report DataFrame to a JSON file for structured data interchange.
report_df.to_json(f"{output_dir}/classification_report.json", indent=4)

# %%
# Create a dictionary to store the overall performance metrics.
# This makes it easy to save these metrics in a structured format like JSON.
overall_metrics = {
    "accuracy": overall_accuracy,
    "precision": overall_precision,
    "recall": overall_recall,
    "f1_score": overall_f1
}

# Save the overall metrics to a JSON file.
# The 'w' mode opens the file for writing, and 'indent=4' makes the JSON file human-readable.
with open(f"{output_dir}/overall_metrics.json", "w") as f:
    import json
    json.dump(overall_metrics, f, indent=4)

# Save the true and predicted labels to NumPy files.
# This allows for more detailed analysis later without needing to re-run the model.
np.save(f"{output_dir}/y_true.npy", y_true_classes)
np.save(f"{output_dir}/y_pred.npy", y_pred_classes)

# %%
# --- Save Final Model for conversion and  Deployment ---

# --- Define Save Path ---
# This saves the final, trained model in the native Keras v3 format.
# This single file contains the architecture, weights, and optimizer state.
final_model_path = "/content/drive/MyDrive/major_project/models/keras_models/bilstm_mixed_model.keras"

# --- Save Model ---
print(f"\nSaving the final trained model to: {final_model_path}")
model.save(final_model_path)
print("Model saved successfully.")
print("\nThis file can now be loaded elsewhere for inference or TFLite conversion.")
# Out:
# Saving the final trained model to: /content/drive/MyDrive/major_project/models/keras_models/bilstm_mixed_model.keras
# Model saved successfully.
#
# This file can now be loaded elsewhere for inference or TFLite conversion.

# %%
# ------------------------------------------- END OF TRAINING ------------------------

# %%
# ---  Core Paths ---
DRIVE_BASE_PATH = '/content/drive/MyDrive/major_project'

# Input paths
FEATURES_PATH = os.path.join(DRIVE_BASE_PATH, 'features')
KERAS_MODEL_PATH = os.path.join(DRIVE_BASE_PATH, 'models/keras_models/bilstm_mixed_model.keras')

# Output paths
TFLITE_MODELS_DIR = os.path.join(DRIVE_BASE_PATH, 'models/tflite_models')
os.makedirs(TFLITE_MODELS_DIR, exist_ok=True) # Ensure the directory exists

MODEL_PATH_TFLITE_STANDARD = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_standard.tflite')
MODEL_PATH_TFLITE_PTQ = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_dynamic.tflite')
MODEL_PATH_TFLITE_PTQ_FULL = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_full.tflite')
MODEL_PATH_TFLITE_PTQ_FULL_FLOAT = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_full_float.tflite')
MODEL_PATH_TFLITE_PTQ_FLOAT16 = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_float16.tflite')

print("\nAll paths configured.")
# Out:
# All paths configured.

# %%
# ==============================================================================
# Load Baseline Keras Model
# ==============================================================================
print(f"Loading baseline Keras model from: {KERAS_MODEL_PATH}")

model_keras = tf.keras.models.load_model(
    KERAS_MODEL_PATH,
)

print("✅ Baseline Keras model loaded successfully.")
model_keras.summary()
# Out:
# Loading baseline Keras model from: /content/drive/MyDrive/major_project/models/keras_models/bilstm_mixed_model.keras
# ✅ Baseline Keras model loaded successfully.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 75, 177)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 1024)           │     2,826,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 33)             │        16,929 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,116,197 (38.59 MB)
#  Trainable params: 3,371,041 (12.86 MB)
#  Non-trainable params: 3,072 (12.00 KB)
#  Optimizer params: 6,742,084 (25.72 MB)

# %%
# ==============================================================================
# Standard TFLite Conversion
# ==============================================================================
print(f"Converting Keras model to standard TFLite format...")

converter = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]
converter.experimental_enable_resource_variables = True
tflite_model_standard = converter.convert()

with open(MODEL_PATH_TFLITE_STANDARD, 'wb') as f:
    f.write(tflite_model_standard)

print(f"✅ Standard TFLite model saved to: {MODEL_PATH_TFLITE_STANDARD}")
# Out:
# Converting Keras model to standard TFLite format...
# Saved artifact at '/tmp/tmpp5ta4wpx'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138371814135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Standard TFLite model saved to: /content/drive/MyDrive/major_project/models/tflite_models/bilstm_mixed_model_standard.tflite

# %%
# ==============================================================================
# Post-Training Quantization (Weight Analysis)
# ==============================================================================

import numpy as np

print(f"🔧 Applying Post-Training Quantization...")

# === Print original model precision ===
float_weights = 0
total_weights = 0
for layer in model_keras.layers:
    for weight in layer.get_weights():
        total_weights += weight.size
        if weight.dtype == np.float32:
            float_weights += weight.size

print(f"🔍 Original model precision:")
print(f"   - Total weights: {total_weights}")
print(f"   - Float32 weights: {float_weights} ({(float_weights/total_weights)*100:.2f}%)")
# Out:
# 🔧 Applying Post-Training Quantization...
# 🔍 Original model precision:
#    - Total weights: 3374113
#    - Float32 weights: 3374113 (100.00%)

# %%
# ------------------------------------------------------------------------------
# Dynamic Range Quantization
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Dynamic Range Quantization...")

converter_dynamic = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_dynamic.optimizations = [tf.lite.Optimize.DEFAULT]

converter_dynamic.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

tflite_model_ptq = converter_dynamic.convert()
with open(MODEL_PATH_TFLITE_PTQ, 'wb') as f:
    f.write(tflite_model_ptq)

print(f"✅ Dynamic Range Quantized model saved at: {MODEL_PATH_TFLITE_PTQ}")
print(f"   → Weights: int8, Activations: float32, Ops: Builtins")
# Out:
# 📦 Converting using Dynamic Range Quantization...
# Saved artifact at '/tmp/tmpqnkph2tv'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138371814135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Dynamic Range Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/bilstm_mixed_model_ptq_dynamic.tflite
#    → Weights: int8, Activations: float32, Ops: Builtins

# %%
# ------------------------------------------------------------------------------
#  Full Integer Quantization, Inputs/Outputs: int8
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Full Integer Quantization...")

# Define a representative dataset for full integer quantization.
# A small subset of the training data is used for calibration.
# The data needs to be in the format expected by the model's input layer.
def representative_data_gen():
    # Use a small subset of the training data for calibration
    num_calibration_steps = 500  # You can adjust this number
    for i in range(num_calibration_steps):
        # Provide the data with the expected input shape and data type
        yield [X_train[i:i+1].astype(np.float32)]



converter_full = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_full.optimizations = [tf.lite.Optimize.DEFAULT]
converter_full.representative_dataset = representative_data_gen

# # --- FORCE INT8 INPUT AND OUTPUT ---
converter_full.inference_input_type = tf.int8
converter_full.inference_output_type = tf.int8

converter_full.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

tflite_model_full = converter_full.convert()
with open(MODEL_PATH_TFLITE_PTQ_FULL, 'wb') as f:
    f.write(tflite_model_full)

print(f"✅ Full Integer Quantized model saved at: {MODEL_PATH_TFLITE_PTQ_FULL}")
print(f"   → Weights: int8, Activations: int8, Ops: Builtins")
# Out:
# 📦 Converting using Full Integer Quantization...
# Saved artifact at '/tmp/tmp_012snrk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138371814135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ Full Integer Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/bilstm_mixed_model_ptq_full.tflite
#    → Weights: int8, Activations: int8, Ops: Builtins

# %%
# ------------------------------------------------------------------------------
#  Full Integer Quantization with Float32 IO/OP
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Full Integer Quantization...")

# Define a representative dataset for full integer quantization.
# A small subset of the training data is used for calibration.
# The data needs to be in the format expected by the model's input layer.
def representative_data_gen():
    # Use a small subset of the training data for calibration
    num_calibration_steps = 500  # You can adjust this number
    for i in range(num_calibration_steps):
        # Provide the data with the expected input shape and data type
        yield [X_train[i:i+1].astype(np.float32)]



converter_full_float = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_full_float.optimizations = [tf.lite.Optimize.DEFAULT]
converter_full_float.representative_dataset = representative_data_gen


converter_full_float.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

tflite_model_full_float = converter_full_float.convert()
with open(MODEL_PATH_TFLITE_PTQ_FULL_FLOAT, 'wb') as f:
    f.write(tflite_model_full_float)

print(f"✅ Full Integer Quantized model saved at: {MODEL_PATH_TFLITE_PTQ_FULL_FLOAT}")
print(f"   → Weights: int8, Activations: int8, Inputs/Outputs: float32, Ops: Builtins")
# Out:
# 📦 Converting using Full Integer Quantization...
# Saved artifact at '/tmp/tmplsbg30h9'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138371814135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ Full Integer Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/bilstm_mixed_model_ptq_full_float.tflite
#    → Weights: int8, Activations: int8, Inputs/Outputs: float32, Ops: Builtins

# %%
# ------------------------------------------------------------------------------
# Float16 quantization
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Dynamic Range Quantization...")

converter_float16 = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_float16.optimizations = [tf.lite.Optimize.DEFAULT]

converter_float16.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]
converter_float16.target_spec.supported_types = [tf.float16]
tflite_model_ptq = converter_float16.convert()
with open(MODEL_PATH_TFLITE_PTQ_FLOAT16, 'wb') as f:
    f.write(tflite_model_ptq)

print(f"✅ Dynamic Range Quantized model saved at: {MODEL_PATH_TFLITE_PTQ_FLOAT16}")
print(f"   → Weights: float16, Activations: float32, Ops: Builtins")
# Out:
# 📦 Converting using Dynamic Range Quantization...
# Saved artifact at '/tmp/tmp5phwyudk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138371814135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138371814142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Dynamic Range Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/bilstm_mixed_model_ptq_float16.tflite
#    → Weights: float16, Activations: float32, Ops: Builtins

# %%
# ==============================================================================
# Load All Models and Compare Sizes
# ==============================================================================
print("Loading all TFLite models into interpreters for evaluation...")
interpreter_standard = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_STANDARD)
interpreter_standard.allocate_tensors()
interpreter_ptq = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ)
interpreter_ptq.allocate_tensors()
interpreter_full_ptq = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ_FULL)
interpreter_full_ptq.allocate_tensors()
interpreter_full_ptq_float = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ_FULL_FLOAT)
interpreter_full_ptq_float.allocate_tensors()
interpreter_float16 = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ_FLOAT16)
interpreter_float16.allocate_tensors()
print("All models loaded.")

# --- Display Model Sizes ---
size_keras = os.path.getsize(KERAS_MODEL_PATH) / 1024
size_tflite_standard = os.path.getsize(MODEL_PATH_TFLITE_STANDARD) / 1024
size_tflite_ptq = os.path.getsize(MODEL_PATH_TFLITE_PTQ) / 1024
size_tflite_full_ptq = os.path.getsize(MODEL_PATH_TFLITE_PTQ_FULL) / 1024
size_tflite_full_ptq_float = os.path.getsize(MODEL_PATH_TFLITE_PTQ_FULL_FLOAT) / 1024
size_tflite_float16 = os.path.getsize(MODEL_PATH_TFLITE_PTQ_FLOAT16) / 1024


print("\n" + "="*80)
print(f"{'Model Type':<50} | {'Size (KB)':>15}")
print("-"*80)
print(f"{'Original Keras (.keras)':<50} | {size_keras:>15.2f}")
print(f"{'Standard TFLite':<50} | {size_tflite_standard:>15.2f}")
print(f"{'Post-Training Quantized (PTQ)':<50} | {size_tflite_ptq:>15.2f}")
print(f"{'Full Integer Quantized (PTQ)':<50} | {size_tflite_full_ptq:>15.2f}")
print(f"{'Full Integer Quantized (PTQ) Float32 IO/OP':<50} | {size_tflite_full_ptq_float:>15.2f}")
print(f"{'Float16 Quantized TFLite':<50} | {size_tflite_float16:>15.2f}")
print("="*80)
# Out:
# Loading all TFLite models into interpreters for evaluation...
# All models loaded.
#
# ================================================================================
# Model Type                                         |       Size (KB)
# --------------------------------------------------------------------------------
# Original Keras (.keras)                            |        39573.83
# Standard TFLite                                    |        13611.76
# Post-Training Quantized (PTQ)                      |         3862.01
# Full Integer Quantized (PTQ)                       |         4353.68
# Full Integer Quantized (PTQ) Float32 IO/OP         |         4354.00
# Float16 Quantized TFLite                           |         7034.95
# ================================================================================

# %%
# ==============================================================================
# Evaluate All Models on Test Data
# ==============================================================================
def evaluate_tflite_model(interpreter, x_test, y_test):
    input_details, output_details = interpreter.get_input_details()[0], interpreter.get_output_details()[0]
    y_pred, inference_times = [], []

    for sample in tqdm(x_test, desc="Evaluating TFLite Model"):
        sample = np.expand_dims(sample, axis=0).astype(input_details['dtype'])
        interpreter.set_tensor(input_details['index'], sample)
        start_time = time.time()
        interpreter.invoke()
        inference_times.append(time.time() - start_time)
        y_pred.append(np.argmax(interpreter.get_tensor(output_details['index'])))

    return accuracy_score(np.argmax(y_test, axis=1), y_pred), np.mean(inference_times) * 1000

# --- Evaluate Models ---
print("Evaluating models on the test set...")
loss_keras, acc_keras = model_keras.evaluate(X_test, y_test, verbose=0)
# Measure Keras inference time by averaging over 100 predictions
time_keras = np.mean([timeit.timeit(lambda: model_keras.predict(np.expand_dims(X_test[i], axis=0), verbose=0), number=1) for i in range(100)]) * 1000

acc_standard, time_standard = evaluate_tflite_model(interpreter_standard, X_test, y_test)
acc_ptq, time_ptq = evaluate_tflite_model(interpreter_ptq, X_test, y_test)
acc_full_ptq, time_full_ptq = evaluate_tflite_model(interpreter_full_ptq, X_test, y_test)
acc_full_ptq_float, time_full_ptq_float = evaluate_tflite_model(interpreter_full_ptq_float, X_test, y_test)
acc_float16, time_float16 = evaluate_tflite_model(interpreter_float16, X_test, y_test)


# --- Display Results ---
results_df = pd.DataFrame({
    "Model Type": ["Original Keras", "Standard TFLite", "Dynamic PTQ TFLite", "Full Integer PTQ TFLite", "Full Integer PTQ (Float IO)", "Float16 PTQ TFLite"],
    "Accuracy": [f"{acc_keras:.4f}", f"{acc_standard:.4f}", f"{acc_ptq:.4f}", f"{acc_full_ptq:.4f}", f"{acc_full_ptq_float:.4f}", f"{acc_float16:.4f}"],
    "Avg Inference Time (ms)": [f"{time_keras:.4f}", f"{time_standard:.4f}", f"{time_ptq:.4f}", f"{time_full_ptq:.4f}", f"{time_full_ptq_float:.4f}", f"{time_float16:.4f}"]
})

print("\n\n" + "="*65)
print("          Model Performance on Test Set        ")
print("="*65)
print(results_df.to_string(index=False))
print("="*65)
# Out:
# Evaluating models on the test set...
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# =================================================================
#           Model Performance on Test Set
# =================================================================
#                  Model Type Accuracy Avg Inference Time (ms)
#              Original Keras   0.9343                 77.5350
#             Standard TFLite   0.9343                 78.7099
#          Dynamic PTQ TFLite   0.9343                 20.8865
#     Full Integer PTQ TFLite   0.0303                 19.8831
# Full Integer PTQ (Float IO)   0.8851                 19.8520
#          Float16 PTQ TFLite   0.9343                 76.2338
# =================================================================

# %%
import pprint

# ==============================================================================
# pretty print dtype
# ==============================================================================
models = {
    "Standard Float32": MODEL_PATH_TFLITE_STANDARD,
    "Dynamic PTQ": MODEL_PATH_TFLITE_PTQ,
    "Full Integer PTQ": MODEL_PATH_TFLITE_PTQ_FULL,
    "Full Integer w/Float I/O": MODEL_PATH_TFLITE_PTQ_FULL_FLOAT,
    "Float16 PTQ": MODEL_PATH_TFLITE_PTQ_FLOAT16
}

summary = {}

for label, path in models.items():
    interpreter = tf.lite.Interpreter(model_path=path)
    interpreter.allocate_tensors()

    # Input/output types
    inp = interpreter.get_input_details()[0]
    out = interpreter.get_output_details()[0]
    io_dtype = (inp['dtype'], out['dtype'])

    # Tensor details
    details = interpreter.get_tensor_details()
    weights_dtype = set()
    bias_dtype = set()
    act_quantized = False

    for td in details:
        name = td['name'].lower()
        dtype = td['dtype']
        qpar = td.get('quantization_parameters', {})
        scales = qpar.get('scales', None)
        has_q = scales is not None and len(scales) > 0

        if 'kernel' in name or 'weight' in name:
            weights_dtype.add(dtype)
        if 'bias' in name:
            bias_dtype.add(dtype)
        if has_q and not ('bias' in name):
            act_quantized = True

    summary[label] = {
        "Weights dtype": list(weights_dtype),
        "Activations quantized": act_quantized,
        "Bias dtype": list(bias_dtype),
        "Input/Output dtype": io_dtype
    }

pprint.pprint(summary, sort_dicts=False, indent=2)
# Out:
# { 'Standard Float32': { 'Weights dtype': [],
#                         'Activations quantized': False,
#                         'Bias dtype': [<class 'numpy.float32'>],
#                         'Input/Output dtype': ( <class 'numpy.float32'>,
#                                                 <class 'numpy.float32'>)},
#   'Dynamic PTQ': { 'Weights dtype': [],
#                    'Activations quantized': True,
#                    'Bias dtype': [<class 'numpy.float32'>],
#                    'Input/Output dtype': ( <class 'numpy.float32'>,
#                                            <class 'numpy.float32'>)},
#   'Full Integer PTQ': { 'Weights dtype': [],
#                         'Activations quantized': True,
#                         'Bias dtype': [<class 'numpy.int8'>],
#                         'Input/Output dtype': ( <class 'numpy.int8'>,
#                                                 <class 'numpy.int8'>)},
#   'Full Integer w/Float I/O': { 'Weights dtype': [],
#                                 'Activations quantized': True,
#                                 'Bias dtype': [<class 'numpy.int8'>],
#                                 'Input/Output dtype': ( <class 'numpy.float32'>,
#                                                         <class 'numpy.float32'>)},
#   'Float16 PTQ': { 'Weights dtype': [],
#                    'Activations quantized': False,
#                    'Bias dtype': [<class 'numpy.float32'>],
#                    'Input/Output dtype': ( <class 'numpy.float32'>,
#                                            <class 'numpy.float32'>)}}

# %%
# ==============================================================================
# quantization reference
# ==============================================================================
# https://ai.google.dev/edge/litert/models/post_training_quantization

# %%
from tabulate import tabulate
# ==============================================================================
# tabulate dtype
# ==============================================================================
MODEL_PATH_TFLITE_STANDARD = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_standard.tflite')
MODEL_PATH_TFLITE_PTQ = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_dynamic.tflite')
MODEL_PATH_TFLITE_PTQ_FULL = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_full.tflite')
MODEL_PATH_TFLITE_PTQ_FULL_FLOAT = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_full_float.tflite')
MODEL_PATH_TFLITE_PTQ_FLOAT16 = os.path.join(TFLITE_MODELS_DIR, 'bilstm_mixed_model_ptq_float16.tflite')

models_tflite = {
    "Standard Float32": MODEL_PATH_TFLITE_STANDARD,
    "Dynamic PTQ": MODEL_PATH_TFLITE_PTQ,
    "Full Integer PTQ": MODEL_PATH_TFLITE_PTQ_FULL,
    "Full Integer w/Float I/O": MODEL_PATH_TFLITE_PTQ_FULL_FLOAT,
    "Float16 PTQ": MODEL_PATH_TFLITE_PTQ_FLOAT16
}

table_data = []

# Analyze Keras model
try:
    keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH)
    weights = keras_model.weights
    weight_dtypes = set()
    bias_dtypes = set()

    for w in weights:
        name = w.name.lower()
        dtype = str(w.dtype)
        if 'bias' in name:
            bias_dtypes.add(dtype)
        else:
            weight_dtypes.add(dtype)

    try:
        input_dtype = keras_model.input.dtype.name
        output_dtype = keras_model.output.dtype.name
    except Exception:
        input_dtype = output_dtype = "n/a"

    table_data.append([
        "Keras Model",
        ', '.join(weight_dtypes) if weight_dtypes else "n/a",
        "Float",  # Keras models are float by default
        ', '.join(bias_dtypes) if bias_dtypes else "n/a",
        f"{input_dtype} → {output_dtype}"
    ])
except Exception as e:
    print("❌ Error loading Keras model:", e)
    table_data.append(["Keras Model", "n/a", "n/a", "n/a", "n/a"])

# Analyze TFLite models
for label, path in models_tflite.items():
    try:
        interpreter = tf.lite.Interpreter(model_path=path)
        interpreter.allocate_tensors()

        # Input/Output types
        try:
            inp = interpreter.get_input_details()[0]
            out = interpreter.get_output_details()[0]
            io_dtype = f"{inp['dtype'].__name__} → {out['dtype'].__name__}"
        except Exception:
            io_dtype = "n/a"

        # Tensor details
        details = interpreter.get_tensor_details()
        weights_dtype = set()
        bias_dtype = set()
        act_quantized = False

        for td in details:
            name = td.get('name', '').lower()
            dtype = td.get('dtype', None)
            if dtype is not None:
                dtype_name = dtype.__name__
            else:
                dtype_name = "n/a"

            qpar = td.get('quantization_parameters', {})
            scales = qpar.get('scales', [])
            has_q = scales is not None and len(scales) > 0

            if 'kernel' in name or 'weight' in name:
                weights_dtype.add(dtype_name)
            elif 'bias' in name:
                bias_dtype.add(dtype_name)
            if has_q and 'bias' not in name:
                act_quantized = True

        table_data.append([
            label,
            ', '.join(weights_dtype) if weights_dtype else "n/a",
            "Quantized" if act_quantized else "Float",
            ', '.join(bias_dtype) if bias_dtype else "n/a",
            io_dtype
        ])
    except Exception as e:
        print(f"❌ Error processing {label} model:", e)
        table_data.append([label, "n/a", "n/a", "n/a", "n/a"])

# Print the final table
headers = ["Conversion Type", "Weights", "Activations", "Bias", "Input/Output"]
print(tabulate(table_data, headers=headers, tablefmt="grid"))
# Out:
# +--------------------------+-----------+---------------+---------+-------------------+
# | Conversion Type          | Weights   | Activations   | Bias    | Input/Output      |
# +==========================+===========+===============+=========+===================+
# | Keras Model              | float32   | Float         | float32 | n/a → n/a         |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Standard Float32         | n/a       | Float         | float32 | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Dynamic PTQ              | n/a       | Quantized     | float32 | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Full Integer PTQ         | n/a       | Quantized     | int8    | int8 → int8       |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Full Integer w/Float I/O | n/a       | Quantized     | int8    | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Float16 PTQ              | n/a       | Float         | float32 | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
