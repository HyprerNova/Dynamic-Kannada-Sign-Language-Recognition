# %%
# --- Installation ---
print("Installing required libraries...")
# !pip install -q tensorflow tensorflow_model_optimization scikit-learn matplotlib seaborn matplotlib mediapipe opencv-python tabulate
print("Installation complete.")
# Out:
# Installing required libraries...
# Installation complete.

# %%
# --- Standard Libraries ---
import os
import time
import timeit

# --- Scientific and Data Handling Libraries ---
import numpy as np
import pandas as pd

# --- Visualization Libraries ---
import matplotlib.pyplot as plt
import seaborn as sns

# --- Machine Learning Libraries ---
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# --- Deep Learning Libraries ---
import tensorflow as tf
import tensorflow_model_optimization as tfmot
import keras
from tensorflow.keras import layers, models, callbacks, regularizers, utils

# --- Computer Vision Library ---
import cv2

# --- Google Colab ---
from google.colab import drive

# --- Progress Bar ---
from tqdm.notebook import tqdm

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# --- Reproducibility ---
# Set a seed for random operations to ensure that results are consistent across runs.
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

print("\nLibraries imported and seed set for reproducibility.")
# Out:
# Libraries imported and seed set for reproducibility.

# %%
# --- Mount Google Drive ---
print("Mounting Google Drive...")
drive.mount('/content/drive')
# Out:
# Mounting Google Drive...
# Mounted at /content/drive

# %%
# --- Load Data (mediapipe features) ---
DATA_PATH = '/content/drive/MyDrive/major_project/features/'
X_path = os.path.join(DATA_PATH, 'X_original_increased_sampled_mixture_augmentation.npy')
y_path = os.path.join(DATA_PATH, 'y_original_increased_sampled_mixture_augmentation.npy')

print(f"\nLoading data from {DATA_PATH}...")
X = np.load(X_path)
y = np.load(y_path)

print(f"\nData loaded. X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Loading data from /content/drive/MyDrive/major_project/features/...
#
# Data loaded. X shape: (3960, 75, 177), y shape: (3960, 33)

# %%
# --- Split Data (70% Train, 20% Test, 10% Validation) ---
print("Splitting data into training, validation, and test sets...")

# First split: Separate 20% for the test set.
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, random_state=SEED, stratify=y
)

# Second split: Split the remaining data (80%) into training (70%) and validation (10%).
# The validation size relative to the temp set is 10 / (70 + 10) = 0.125
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.125, random_state=SEED, stratify=y_temp
)

print("\nData splitting complete.")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape:   {X_val.shape}, y_val shape:   {y_val.shape}")
print(f"X_test shape:  {X_test.shape}, y_test shape:  {y_test.shape}")

# For example, if:
# Class A has 100 samples
# Class B has 70 samples
# Class C has 90 samples
# Then the 70-10-20 split with stratify will give:
# Train: 70% of A, B, C
# Val: 10% of A, B, C
# Test: 20% of A, B, C
# Out:
# Splitting data into training, validation, and test sets...
#
# Data splitting complete.
# X_train shape: (2772, 75, 177), y_train shape: (2772, 33)
# X_val shape:   (396, 75, 177), y_val shape:   (396, 33)
# X_test shape:  (792, 75, 177), y_test shape:  (792, 33)

# %%
# --- load model ---
def create_improved_unidirectional_lstm_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # First LSTM layer (TFLite-compatible)
    x = LSTM(
        256,
        return_sequences=True,
        activation='tanh',
        recurrent_activation='sigmoid',
        unroll=True,
        kernel_regularizer=l2(0.01),
        recurrent_dropout=0.2,
        use_bias=True
    )(inputs)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)

    # Second LSTM layer
    x = LSTM(
        128,
        return_sequences=False,
        activation='tanh',
        recurrent_activation='sigmoid',
        unroll=True,
        kernel_regularizer=l2(0.01),
        recurrent_dropout=0.2,
        use_bias=True
    )(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)

    # Dense layers
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# --- Get Model Parameters ---
input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# --- Build and Compile ---
print(f"Building model with input shape: {input_shape} and {num_classes} classes.")
model = create_improved_unidirectional_lstm_model(input_shape, num_classes)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
model.summary()
# Out:
# Building model with input shape: (75, 177) and 33 classes.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 75, 177)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 75, 256)        │       444,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 75, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 33)             │         4,257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 664,353 (2.53 MB)
#  Trainable params: 663,329 (2.53 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
# --- Define Callbacks ---
# Define the path for saving the best model using the .keras format
checkpoint_path = "/content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras"

# Stop training when validation loss doesn't improve for 10 epochs
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=15, restore_best_weights=True, verbose=1
)
# Save the best model based on validation accuracy
model_checkpoint = callbacks.ModelCheckpoint(
    filepath=checkpoint_path, monitor='val_accuracy', save_best_only=True, verbose=1
)
# Reduce learning rate when validation loss plateaus
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1
)

# %%
# --- Train the Model ---
print("\nStarting model training...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=200,  # A high number; EarlyStopping will find the optimal point
    batch_size=32,
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)
print("\nModel training complete.")

# --- Extract Best Epoch Based on Validation Accuracy ---
val_acc = history.history['val_accuracy']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
train_loss = history.history['loss']

best_epoch = np.argmax(val_acc)
print(f"\nBest Epoch: {best_epoch + 1}")
print(f"Train Accuracy   : {train_acc[best_epoch]*100:.2f}%")
print(f"Validation Accuracy: {val_acc[best_epoch]*100:.2f}%")
print(f"Train Loss       : {train_loss[best_epoch]:.4f}")
print(f"Validation Loss  : {val_loss[best_epoch]:.4f}")
# Out:
# Starting model training...
# Epoch 1/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 946ms/step - accuracy: 0.0366 - loss: 11.7728
# Epoch 1: val_accuracy improved from -inf to 0.05808, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.0366 - loss: 11.7710 - val_accuracy: 0.0581 - val_loss: 10.7301 - learning_rate: 1.0000e-04
# Epoch 2/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0415 - loss: 11.1572
# Epoch 2: val_accuracy improved from 0.05808 to 0.09091, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.0415 - loss: 11.1555 - val_accuracy: 0.0909 - val_loss: 10.2074 - learning_rate: 1.0000e-04
# Epoch 3/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0475 - loss: 10.6066
# Epoch 3: val_accuracy improved from 0.09091 to 0.13636, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.0475 - loss: 10.6052 - val_accuracy: 0.1364 - val_loss: 9.6851 - learning_rate: 1.0000e-04
# Epoch 4/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0710 - loss: 10.0831
# Epoch 4: val_accuracy improved from 0.13636 to 0.16919, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.0710 - loss: 10.0821 - val_accuracy: 0.1692 - val_loss: 9.1929 - learning_rate: 1.0000e-04
# Epoch 5/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0830 - loss: 9.6563
# Epoch 5: val_accuracy improved from 0.16919 to 0.19949, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.0831 - loss: 9.6554 - val_accuracy: 0.1995 - val_loss: 8.7481 - learning_rate: 1.0000e-04
# Epoch 6/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0929 - loss: 9.2563
# Epoch 6: val_accuracy did not improve from 0.19949
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.0930 - loss: 9.2554 - val_accuracy: 0.1970 - val_loss: 8.3991 - learning_rate: 1.0000e-04
# Epoch 7/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1025 - loss: 8.8864
# Epoch 7: val_accuracy improved from 0.19949 to 0.23990, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.1026 - loss: 8.8856 - val_accuracy: 0.2399 - val_loss: 7.9822 - learning_rate: 1.0000e-04
# Epoch 8/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1121 - loss: 8.5185
# Epoch 8: val_accuracy did not improve from 0.23990
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.1122 - loss: 8.5176 - val_accuracy: 0.2020 - val_loss: 7.7558 - learning_rate: 1.0000e-04
# Epoch 9/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1444 - loss: 8.2126
# Epoch 9: val_accuracy improved from 0.23990 to 0.24495, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.1443 - loss: 8.2111 - val_accuracy: 0.2449 - val_loss: 7.4090 - learning_rate: 1.0000e-04
# Epoch 10/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1414 - loss: 7.8921
# Epoch 10: val_accuracy improved from 0.24495 to 0.27525, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.1415 - loss: 7.8915 - val_accuracy: 0.2753 - val_loss: 7.1072 - learning_rate: 1.0000e-04
# Epoch 11/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1565 - loss: 7.6115
# Epoch 11: val_accuracy improved from 0.27525 to 0.29293, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.1565 - loss: 7.6107 - val_accuracy: 0.2929 - val_loss: 6.8453 - learning_rate: 1.0000e-04
# Epoch 12/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1615 - loss: 7.3540
# Epoch 12: val_accuracy improved from 0.29293 to 0.29798, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.1616 - loss: 7.3535 - val_accuracy: 0.2980 - val_loss: 6.5731 - learning_rate: 1.0000e-04
# Epoch 13/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1743 - loss: 7.1195
# Epoch 13: val_accuracy improved from 0.29798 to 0.32576, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.1744 - loss: 7.1190 - val_accuracy: 0.3258 - val_loss: 6.3745 - learning_rate: 1.0000e-04
# Epoch 14/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1880 - loss: 6.9191
# Epoch 14: val_accuracy did not improve from 0.32576
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.1880 - loss: 6.9185 - val_accuracy: 0.3258 - val_loss: 6.1469 - learning_rate: 1.0000e-04
# Epoch 15/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1898 - loss: 6.6996
# Epoch 15: val_accuracy improved from 0.32576 to 0.35606, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.1898 - loss: 6.6992 - val_accuracy: 0.3561 - val_loss: 5.9588 - learning_rate: 1.0000e-04
# Epoch 16/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2152 - loss: 6.4420
# Epoch 16: val_accuracy did not improve from 0.35606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.2151 - loss: 6.4415 - val_accuracy: 0.3535 - val_loss: 5.7608 - learning_rate: 1.0000e-04
# Epoch 17/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2128 - loss: 6.2569
# Epoch 17: val_accuracy improved from 0.35606 to 0.36869, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.2127 - loss: 6.2571 - val_accuracy: 0.3687 - val_loss: 5.5793 - learning_rate: 1.0000e-04
# Epoch 18/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2226 - loss: 6.0627
# Epoch 18: val_accuracy improved from 0.36869 to 0.41162, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.2227 - loss: 6.0624 - val_accuracy: 0.4116 - val_loss: 5.4176 - learning_rate: 1.0000e-04
# Epoch 19/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2448 - loss: 5.9110
# Epoch 19: val_accuracy did not improve from 0.41162
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.2447 - loss: 5.9110 - val_accuracy: 0.3889 - val_loss: 5.2617 - learning_rate: 1.0000e-04
# Epoch 20/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2485 - loss: 5.7406
# Epoch 20: val_accuracy improved from 0.41162 to 0.41414, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.2485 - loss: 5.7405 - val_accuracy: 0.4141 - val_loss: 5.1358 - learning_rate: 1.0000e-04
# Epoch 21/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2501 - loss: 5.6082
# Epoch 21: val_accuracy improved from 0.41414 to 0.43687, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.2501 - loss: 5.6076 - val_accuracy: 0.4369 - val_loss: 4.9707 - learning_rate: 1.0000e-04
# Epoch 22/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2635 - loss: 5.4390
# Epoch 22: val_accuracy did not improve from 0.43687
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.2634 - loss: 5.4389 - val_accuracy: 0.4066 - val_loss: 4.8946 - learning_rate: 1.0000e-04
# Epoch 23/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2697 - loss: 5.3703
# Epoch 23: val_accuracy did not improve from 0.43687
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.2697 - loss: 5.3698 - val_accuracy: 0.4141 - val_loss: 4.7303 - learning_rate: 1.0000e-04
# Epoch 24/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2891 - loss: 5.1612
# Epoch 24: val_accuracy did not improve from 0.43687
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.2891 - loss: 5.1609 - val_accuracy: 0.4141 - val_loss: 4.6233 - learning_rate: 1.0000e-04
# Epoch 25/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3133 - loss: 4.9813
# Epoch 25: val_accuracy improved from 0.43687 to 0.44444, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.3131 - loss: 4.9815 - val_accuracy: 0.4444 - val_loss: 4.4444 - learning_rate: 1.0000e-04
# Epoch 26/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3040 - loss: 4.8891
# Epoch 26: val_accuracy did not improve from 0.44444
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.3038 - loss: 4.8896 - val_accuracy: 0.4268 - val_loss: 4.3421 - learning_rate: 1.0000e-04
# Epoch 27/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3016 - loss: 4.8161
# Epoch 27: val_accuracy improved from 0.44444 to 0.45707, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.3016 - loss: 4.8160 - val_accuracy: 0.4571 - val_loss: 4.3116 - learning_rate: 1.0000e-04
# Epoch 28/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2964 - loss: 4.7274
# Epoch 28: val_accuracy did not improve from 0.45707
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.2965 - loss: 4.7270 - val_accuracy: 0.4545 - val_loss: 4.1522 - learning_rate: 1.0000e-04
# Epoch 29/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3070 - loss: 4.5742
# Epoch 29: val_accuracy improved from 0.45707 to 0.47222, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.3071 - loss: 4.5741 - val_accuracy: 0.4722 - val_loss: 4.0710 - learning_rate: 1.0000e-04
# Epoch 30/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3407 - loss: 4.4615
# Epoch 30: val_accuracy did not improve from 0.47222
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.3406 - loss: 4.4614 - val_accuracy: 0.4571 - val_loss: 3.9845 - learning_rate: 1.0000e-04
# Epoch 31/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3475 - loss: 4.3490
# Epoch 31: val_accuracy improved from 0.47222 to 0.49747, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.3475 - loss: 4.3491 - val_accuracy: 0.4975 - val_loss: 3.8421 - learning_rate: 1.0000e-04
# Epoch 32/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3439 - loss: 4.2763
# Epoch 32: val_accuracy improved from 0.49747 to 0.51515, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.3439 - loss: 4.2764 - val_accuracy: 0.5152 - val_loss: 3.7540 - learning_rate: 1.0000e-04
# Epoch 33/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3475 - loss: 4.1720
# Epoch 33: val_accuracy did not improve from 0.51515
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.3478 - loss: 4.1716 - val_accuracy: 0.5101 - val_loss: 3.6393 - learning_rate: 1.0000e-04
# Epoch 34/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3714 - loss: 4.0534
# Epoch 34: val_accuracy did not improve from 0.51515
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.3711 - loss: 4.0539 - val_accuracy: 0.4924 - val_loss: 3.6458 - learning_rate: 1.0000e-04
# Epoch 35/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3638 - loss: 4.0245
# Epoch 35: val_accuracy improved from 0.51515 to 0.53283, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.3638 - loss: 4.0241 - val_accuracy: 0.5328 - val_loss: 3.4751 - learning_rate: 1.0000e-04
# Epoch 36/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3795 - loss: 3.9422
# Epoch 36: val_accuracy improved from 0.53283 to 0.56061, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.3794 - loss: 3.9421 - val_accuracy: 0.5606 - val_loss: 3.3974 - learning_rate: 1.0000e-04
# Epoch 37/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4007 - loss: 3.8250
# Epoch 37: val_accuracy did not improve from 0.56061
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.4007 - loss: 3.8250 - val_accuracy: 0.5530 - val_loss: 3.3410 - learning_rate: 1.0000e-04
# Epoch 38/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3886 - loss: 3.7928
# Epoch 38: val_accuracy did not improve from 0.56061
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.3887 - loss: 3.7924 - val_accuracy: 0.5354 - val_loss: 3.2914 - learning_rate: 1.0000e-04
# Epoch 39/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4214 - loss: 3.6738
# Epoch 39: val_accuracy improved from 0.56061 to 0.56566, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.4211 - loss: 3.6740 - val_accuracy: 0.5657 - val_loss: 3.2437 - learning_rate: 1.0000e-04
# Epoch 40/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4282 - loss: 3.5828
# Epoch 40: val_accuracy did not improve from 0.56566
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.4281 - loss: 3.5829 - val_accuracy: 0.5581 - val_loss: 3.1476 - learning_rate: 1.0000e-04
# Epoch 41/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4254 - loss: 3.5299
# Epoch 41: val_accuracy improved from 0.56566 to 0.60101, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.4253 - loss: 3.5299 - val_accuracy: 0.6010 - val_loss: 3.0480 - learning_rate: 1.0000e-04
# Epoch 42/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4518 - loss: 3.4256
# Epoch 42: val_accuracy did not improve from 0.60101
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.4517 - loss: 3.4258 - val_accuracy: 0.5758 - val_loss: 3.0315 - learning_rate: 1.0000e-04
# Epoch 43/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4458 - loss: 3.3942
# Epoch 43: val_accuracy did not improve from 0.60101
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4458 - loss: 3.3943 - val_accuracy: 0.5556 - val_loss: 3.0134 - learning_rate: 1.0000e-04
# Epoch 44/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4759 - loss: 3.2924
# Epoch 44: val_accuracy improved from 0.60101 to 0.61364, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.4758 - loss: 3.2929 - val_accuracy: 0.6136 - val_loss: 2.8628 - learning_rate: 1.0000e-04
# Epoch 45/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4637 - loss: 3.2597
# Epoch 45: val_accuracy improved from 0.61364 to 0.61616, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4637 - loss: 3.2596 - val_accuracy: 0.6162 - val_loss: 2.8132 - learning_rate: 1.0000e-04
# Epoch 46/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4786 - loss: 3.2108
# Epoch 46: val_accuracy did not improve from 0.61616
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.4786 - loss: 3.2106 - val_accuracy: 0.6086 - val_loss: 2.7554 - learning_rate: 1.0000e-04
# Epoch 47/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4756 - loss: 3.1678
# Epoch 47: val_accuracy improved from 0.61616 to 0.63636, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.4758 - loss: 3.1675 - val_accuracy: 0.6364 - val_loss: 2.7280 - learning_rate: 1.0000e-04
# Epoch 48/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5093 - loss: 3.0726
# Epoch 48: val_accuracy improved from 0.63636 to 0.64646, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5092 - loss: 3.0728 - val_accuracy: 0.6465 - val_loss: 2.6581 - learning_rate: 1.0000e-04
# Epoch 49/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4917 - loss: 3.0539
# Epoch 49: val_accuracy did not improve from 0.64646
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.4918 - loss: 3.0535 - val_accuracy: 0.6389 - val_loss: 2.6012 - learning_rate: 1.0000e-04
# Epoch 50/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4974 - loss: 2.9777
# Epoch 50: val_accuracy improved from 0.64646 to 0.67424, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.4975 - loss: 2.9777 - val_accuracy: 0.6742 - val_loss: 2.5512 - learning_rate: 1.0000e-04
# Epoch 51/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5287 - loss: 2.8907
# Epoch 51: val_accuracy did not improve from 0.67424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5287 - loss: 2.8907 - val_accuracy: 0.6338 - val_loss: 2.5486 - learning_rate: 1.0000e-04
# Epoch 52/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5252 - loss: 2.8549
# Epoch 52: val_accuracy did not improve from 0.67424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5251 - loss: 2.8550 - val_accuracy: 0.6465 - val_loss: 2.5265 - learning_rate: 1.0000e-04
# Epoch 53/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5424 - loss: 2.7796
# Epoch 53: val_accuracy did not improve from 0.67424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.5424 - loss: 2.7798 - val_accuracy: 0.6035 - val_loss: 2.5981 - learning_rate: 1.0000e-04
# Epoch 54/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5289 - loss: 2.7992
# Epoch 54: val_accuracy improved from 0.67424 to 0.68687, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.5290 - loss: 2.7991 - val_accuracy: 0.6869 - val_loss: 2.3405 - learning_rate: 1.0000e-04
# Epoch 55/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5516 - loss: 2.6994
# Epoch 55: val_accuracy improved from 0.68687 to 0.68939, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5515 - loss: 2.6995 - val_accuracy: 0.6894 - val_loss: 2.3120 - learning_rate: 1.0000e-04
# Epoch 56/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5547 - loss: 2.6945
# Epoch 56: val_accuracy improved from 0.68939 to 0.69444, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.5546 - loss: 2.6945 - val_accuracy: 0.6944 - val_loss: 2.2939 - learning_rate: 1.0000e-04
# Epoch 57/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5787 - loss: 2.5825
# Epoch 57: val_accuracy did not improve from 0.69444
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5784 - loss: 2.5837 - val_accuracy: 0.6667 - val_loss: 2.3485 - learning_rate: 1.0000e-04
# Epoch 58/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5788 - loss: 2.5781
# Epoch 58: val_accuracy improved from 0.69444 to 0.71465, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5787 - loss: 2.5782 - val_accuracy: 0.7146 - val_loss: 2.2018 - learning_rate: 1.0000e-04
# Epoch 59/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6087 - loss: 2.4833
# Epoch 59: val_accuracy did not improve from 0.71465
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.6086 - loss: 2.4836 - val_accuracy: 0.6667 - val_loss: 2.2478 - learning_rate: 1.0000e-04
# Epoch 60/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5903 - loss: 2.4869
# Epoch 60: val_accuracy did not improve from 0.71465
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.5903 - loss: 2.4871 - val_accuracy: 0.6995 - val_loss: 2.1818 - learning_rate: 1.0000e-04
# Epoch 61/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5938 - loss: 2.4518
# Epoch 61: val_accuracy did not improve from 0.71465
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5938 - loss: 2.4521 - val_accuracy: 0.7096 - val_loss: 2.1670 - learning_rate: 1.0000e-04
# Epoch 62/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6047 - loss: 2.4246
# Epoch 62: val_accuracy improved from 0.71465 to 0.72222, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.6048 - loss: 2.4244 - val_accuracy: 0.7222 - val_loss: 2.0502 - learning_rate: 1.0000e-04
# Epoch 63/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6083 - loss: 2.3813
# Epoch 63: val_accuracy did not improve from 0.72222
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.6082 - loss: 2.3815 - val_accuracy: 0.6944 - val_loss: 2.0733 - learning_rate: 1.0000e-04
# Epoch 64/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5910 - loss: 2.3794
# Epoch 64: val_accuracy improved from 0.72222 to 0.73737, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.5911 - loss: 2.3794 - val_accuracy: 0.7374 - val_loss: 1.9968 - learning_rate: 1.0000e-04
# Epoch 65/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6371 - loss: 2.2739
# Epoch 65: val_accuracy improved from 0.73737 to 0.76010, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.6371 - loss: 2.2741 - val_accuracy: 0.7601 - val_loss: 1.9373 - learning_rate: 1.0000e-04
# Epoch 66/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6203 - loss: 2.2544
# Epoch 66: val_accuracy improved from 0.76010 to 0.76768, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.6204 - loss: 2.2543 - val_accuracy: 0.7677 - val_loss: 1.9054 - learning_rate: 1.0000e-04
# Epoch 67/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6649 - loss: 2.1808
# Epoch 67: val_accuracy did not improve from 0.76768
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.6648 - loss: 2.1810 - val_accuracy: 0.7626 - val_loss: 1.8647 - learning_rate: 1.0000e-04
# Epoch 68/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6481 - loss: 2.1929
# Epoch 68: val_accuracy did not improve from 0.76768
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6480 - loss: 2.1929 - val_accuracy: 0.7399 - val_loss: 1.9034 - learning_rate: 1.0000e-04
# Epoch 69/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6574 - loss: 2.1290
# Epoch 69: val_accuracy did not improve from 0.76768
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.6574 - loss: 2.1289 - val_accuracy: 0.7298 - val_loss: 1.8850 - learning_rate: 1.0000e-04
# Epoch 70/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6682 - loss: 2.0851
# Epoch 70: val_accuracy did not improve from 0.76768
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.6680 - loss: 2.0855 - val_accuracy: 0.7551 - val_loss: 1.8366 - learning_rate: 1.0000e-04
# Epoch 71/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6811 - loss: 2.0785
# Epoch 71: val_accuracy did not improve from 0.76768
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6810 - loss: 2.0788 - val_accuracy: 0.7399 - val_loss: 1.7861 - learning_rate: 1.0000e-04
# Epoch 72/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6777 - loss: 2.0378
# Epoch 72: val_accuracy did not improve from 0.76768
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6779 - loss: 2.0376 - val_accuracy: 0.7525 - val_loss: 1.8204 - learning_rate: 1.0000e-04
# Epoch 73/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7032 - loss: 1.9876
# Epoch 73: val_accuracy improved from 0.76768 to 0.78283, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7030 - loss: 1.9879 - val_accuracy: 0.7828 - val_loss: 1.7036 - learning_rate: 1.0000e-04
# Epoch 74/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6977 - loss: 1.9992
# Epoch 74: val_accuracy did not improve from 0.78283
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6976 - loss: 1.9993 - val_accuracy: 0.7348 - val_loss: 1.7745 - learning_rate: 1.0000e-04
# Epoch 75/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6918 - loss: 1.9553
# Epoch 75: val_accuracy did not improve from 0.78283
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.6918 - loss: 1.9555 - val_accuracy: 0.7677 - val_loss: 1.6970 - learning_rate: 1.0000e-04
# Epoch 76/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6936 - loss: 1.9395
# Epoch 76: val_accuracy did not improve from 0.78283
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.6936 - loss: 1.9394 - val_accuracy: 0.7121 - val_loss: 1.8039 - learning_rate: 1.0000e-04
# Epoch 77/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7138 - loss: 1.8935
# Epoch 77: val_accuracy did not improve from 0.78283
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.7138 - loss: 1.8935 - val_accuracy: 0.7778 - val_loss: 1.6622 - learning_rate: 1.0000e-04
# Epoch 78/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7248 - loss: 1.8714
# Epoch 78: val_accuracy did not improve from 0.78283
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.7247 - loss: 1.8718 - val_accuracy: 0.7273 - val_loss: 1.6706 - learning_rate: 1.0000e-04
# Epoch 79/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7231 - loss: 1.8237
# Epoch 79: val_accuracy improved from 0.78283 to 0.81313, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7231 - loss: 1.8243 - val_accuracy: 0.8131 - val_loss: 1.5405 - learning_rate: 1.0000e-04
# Epoch 80/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7317 - loss: 1.8172
# Epoch 80: val_accuracy did not improve from 0.81313
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.7315 - loss: 1.8178 - val_accuracy: 0.7929 - val_loss: 1.5749 - learning_rate: 1.0000e-04
# Epoch 81/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7399 - loss: 1.7708
# Epoch 81: val_accuracy improved from 0.81313 to 0.82071, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.7399 - loss: 1.7709 - val_accuracy: 0.8207 - val_loss: 1.5114 - learning_rate: 1.0000e-04
# Epoch 82/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7495 - loss: 1.7320
# Epoch 82: val_accuracy did not improve from 0.82071
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.7494 - loss: 1.7321 - val_accuracy: 0.8081 - val_loss: 1.5182 - learning_rate: 1.0000e-04
# Epoch 83/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7390 - loss: 1.7214
# Epoch 83: val_accuracy did not improve from 0.82071
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.7389 - loss: 1.7218 - val_accuracy: 0.7273 - val_loss: 1.6512 - learning_rate: 1.0000e-04
# Epoch 84/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7625 - loss: 1.6948
# Epoch 84: val_accuracy did not improve from 0.82071
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7624 - loss: 1.6950 - val_accuracy: 0.7247 - val_loss: 1.8202 - learning_rate: 1.0000e-04
# Epoch 85/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7348 - loss: 1.7678
# Epoch 85: val_accuracy did not improve from 0.82071
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7348 - loss: 1.7675 - val_accuracy: 0.7879 - val_loss: 1.4860 - learning_rate: 1.0000e-04
# Epoch 86/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7585 - loss: 1.6405
# Epoch 86: val_accuracy did not improve from 0.82071
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.7584 - loss: 1.6408 - val_accuracy: 0.7955 - val_loss: 1.4509 - learning_rate: 1.0000e-04
# Epoch 87/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7654 - loss: 1.6411
# Epoch 87: val_accuracy improved from 0.82071 to 0.82828, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.7654 - loss: 1.6411 - val_accuracy: 0.8283 - val_loss: 1.4002 - learning_rate: 1.0000e-04
# Epoch 88/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7738 - loss: 1.5979
# Epoch 88: val_accuracy did not improve from 0.82828
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.7738 - loss: 1.5982 - val_accuracy: 0.8232 - val_loss: 1.4416 - learning_rate: 1.0000e-04
# Epoch 89/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7747 - loss: 1.5789
# Epoch 89: val_accuracy did not improve from 0.82828
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.7747 - loss: 1.5790 - val_accuracy: 0.8131 - val_loss: 1.4629 - learning_rate: 1.0000e-04
# Epoch 90/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7697 - loss: 1.5845
# Epoch 90: val_accuracy did not improve from 0.82828
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7697 - loss: 1.5846 - val_accuracy: 0.6667 - val_loss: 1.8542 - learning_rate: 1.0000e-04
# Epoch 91/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7564 - loss: 1.6512
# Epoch 91: val_accuracy improved from 0.82828 to 0.83838, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7565 - loss: 1.6508 - val_accuracy: 0.8384 - val_loss: 1.3483 - learning_rate: 1.0000e-04
# Epoch 92/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7789 - loss: 1.5718
# Epoch 92: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.7788 - loss: 1.5720 - val_accuracy: 0.8030 - val_loss: 1.3821 - learning_rate: 1.0000e-04
# Epoch 93/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7843 - loss: 1.5353
# Epoch 93: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.7842 - loss: 1.5353 - val_accuracy: 0.8384 - val_loss: 1.2988 - learning_rate: 1.0000e-04
# Epoch 94/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7859 - loss: 1.5181
# Epoch 94: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.7860 - loss: 1.5179 - val_accuracy: 0.8207 - val_loss: 1.3239 - learning_rate: 1.0000e-04
# Epoch 95/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7919 - loss: 1.4836
# Epoch 95: val_accuracy did not improve from 0.83838
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.7919 - loss: 1.4838 - val_accuracy: 0.7980 - val_loss: 1.3276 - learning_rate: 1.0000e-04
# Epoch 96/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7847 - loss: 1.4713
# Epoch 96: val_accuracy improved from 0.83838 to 0.85606, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.7847 - loss: 1.4716 - val_accuracy: 0.8561 - val_loss: 1.2486 - learning_rate: 1.0000e-04
# Epoch 97/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8079 - loss: 1.4519
# Epoch 97: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8079 - loss: 1.4518 - val_accuracy: 0.8131 - val_loss: 1.3969 - learning_rate: 1.0000e-04
# Epoch 98/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8048 - loss: 1.4382
# Epoch 98: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8046 - loss: 1.4385 - val_accuracy: 0.7929 - val_loss: 1.4483 - learning_rate: 1.0000e-04
# Epoch 99/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7925 - loss: 1.4465
# Epoch 99: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.7925 - loss: 1.4465 - val_accuracy: 0.7955 - val_loss: 1.3960 - learning_rate: 1.0000e-04
# Epoch 100/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8012 - loss: 1.4117
# Epoch 100: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8012 - loss: 1.4116 - val_accuracy: 0.8535 - val_loss: 1.2351 - learning_rate: 1.0000e-04
# Epoch 101/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8332 - loss: 1.3428
# Epoch 101: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8329 - loss: 1.3436 - val_accuracy: 0.7854 - val_loss: 1.4092 - learning_rate: 1.0000e-04
# Epoch 102/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7978 - loss: 1.4115
# Epoch 102: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7978 - loss: 1.4114 - val_accuracy: 0.8308 - val_loss: 1.2627 - learning_rate: 1.0000e-04
# Epoch 103/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8162 - loss: 1.3555
# Epoch 103: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8161 - loss: 1.3556 - val_accuracy: 0.8434 - val_loss: 1.1958 - learning_rate: 1.0000e-04
# Epoch 104/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8274 - loss: 1.3130
# Epoch 104: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8272 - loss: 1.3138 - val_accuracy: 0.8485 - val_loss: 1.1994 - learning_rate: 1.0000e-04
# Epoch 105/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8443 - loss: 1.3056
# Epoch 105: val_accuracy did not improve from 0.85606
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.8442 - loss: 1.3058 - val_accuracy: 0.8409 - val_loss: 1.2562 - learning_rate: 1.0000e-04
# Epoch 106/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8058 - loss: 1.3341
# Epoch 106: val_accuracy improved from 0.85606 to 0.86616, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8058 - loss: 1.3340 - val_accuracy: 0.8662 - val_loss: 1.1681 - learning_rate: 1.0000e-04
# Epoch 107/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8300 - loss: 1.2698
# Epoch 107: val_accuracy did not improve from 0.86616
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8299 - loss: 1.2702 - val_accuracy: 0.8460 - val_loss: 1.2102 - learning_rate: 1.0000e-04
# Epoch 108/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8464 - loss: 1.2481
# Epoch 108: val_accuracy did not improve from 0.86616
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8462 - loss: 1.2484 - val_accuracy: 0.7778 - val_loss: 1.4120 - learning_rate: 1.0000e-04
# Epoch 109/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8189 - loss: 1.3323
# Epoch 109: val_accuracy did not improve from 0.86616
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.8189 - loss: 1.3322 - val_accuracy: 0.8485 - val_loss: 1.1827 - learning_rate: 1.0000e-04
# Epoch 110/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8344 - loss: 1.2452
# Epoch 110: val_accuracy did not improve from 0.86616
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8343 - loss: 1.2458 - val_accuracy: 0.8586 - val_loss: 1.1795 - learning_rate: 1.0000e-04
# Epoch 111/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8321 - loss: 1.2667
# Epoch 111: val_accuracy did not improve from 0.86616
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8322 - loss: 1.2665 - val_accuracy: 0.7980 - val_loss: 1.2621 - learning_rate: 1.0000e-04
# Epoch 112/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8427 - loss: 1.2134
# Epoch 112: val_accuracy improved from 0.86616 to 0.88636, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8428 - loss: 1.2131 - val_accuracy: 0.8864 - val_loss: 1.0738 - learning_rate: 5.0000e-05
# Epoch 113/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8542 - loss: 1.1944
# Epoch 113: val_accuracy did not improve from 0.88636
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8543 - loss: 1.1943 - val_accuracy: 0.8712 - val_loss: 1.1258 - learning_rate: 5.0000e-05
# Epoch 114/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8542 - loss: 1.1650
# Epoch 114: val_accuracy did not improve from 0.88636
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.8542 - loss: 1.1650 - val_accuracy: 0.8864 - val_loss: 1.0499 - learning_rate: 5.0000e-05
# Epoch 115/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8674 - loss: 1.1366
# Epoch 115: val_accuracy improved from 0.88636 to 0.89899, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8673 - loss: 1.1367 - val_accuracy: 0.8990 - val_loss: 1.0131 - learning_rate: 5.0000e-05
# Epoch 116/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8701 - loss: 1.1249
# Epoch 116: val_accuracy did not improve from 0.89899
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8701 - loss: 1.1248 - val_accuracy: 0.8965 - val_loss: 1.0058 - learning_rate: 5.0000e-05
# Epoch 117/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8713 - loss: 1.1288
# Epoch 117: val_accuracy did not improve from 0.89899
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.8712 - loss: 1.1291 - val_accuracy: 0.8333 - val_loss: 1.1791 - learning_rate: 5.0000e-05
# Epoch 118/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8550 - loss: 1.1820
# Epoch 118: val_accuracy did not improve from 0.89899
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8550 - loss: 1.1821 - val_accuracy: 0.8712 - val_loss: 1.0872 - learning_rate: 5.0000e-05
# Epoch 119/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8665 - loss: 1.1332
# Epoch 119: val_accuracy did not improve from 0.89899
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8665 - loss: 1.1332 - val_accuracy: 0.8889 - val_loss: 1.0290 - learning_rate: 5.0000e-05
# Epoch 120/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8694 - loss: 1.1113
# Epoch 120: val_accuracy did not improve from 0.89899
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8693 - loss: 1.1116 - val_accuracy: 0.8813 - val_loss: 1.0627 - learning_rate: 5.0000e-05
# Epoch 121/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8681 - loss: 1.1193
# Epoch 121: val_accuracy did not improve from 0.89899
#
# Epoch 121: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.8681 - loss: 1.1192 - val_accuracy: 0.8662 - val_loss: 1.0489 - learning_rate: 5.0000e-05
# Epoch 122/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8779 - loss: 1.0866
# Epoch 122: val_accuracy improved from 0.89899 to 0.90152, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8779 - loss: 1.0868 - val_accuracy: 0.9015 - val_loss: 0.9821 - learning_rate: 2.5000e-05
# Epoch 123/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8819 - loss: 1.0771
# Epoch 123: val_accuracy did not improve from 0.90152
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8819 - loss: 1.0771 - val_accuracy: 0.9015 - val_loss: 0.9816 - learning_rate: 2.5000e-05
# Epoch 124/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8819 - loss: 1.0838
# Epoch 124: val_accuracy improved from 0.90152 to 0.91414, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8818 - loss: 1.0837 - val_accuracy: 0.9141 - val_loss: 0.9636 - learning_rate: 2.5000e-05
# Epoch 125/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8856 - loss: 1.0588
# Epoch 125: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8856 - loss: 1.0589 - val_accuracy: 0.9116 - val_loss: 0.9618 - learning_rate: 2.5000e-05
# Epoch 126/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8875 - loss: 1.0467
# Epoch 126: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8874 - loss: 1.0469 - val_accuracy: 0.9015 - val_loss: 0.9406 - learning_rate: 2.5000e-05
# Epoch 127/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8928 - loss: 1.0516
# Epoch 127: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.8927 - loss: 1.0517 - val_accuracy: 0.8864 - val_loss: 0.9850 - learning_rate: 2.5000e-05
# Epoch 128/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8841 - loss: 1.0511
# Epoch 128: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8841 - loss: 1.0512 - val_accuracy: 0.8965 - val_loss: 0.9736 - learning_rate: 2.5000e-05
# Epoch 129/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9019 - loss: 1.0103
# Epoch 129: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9019 - loss: 1.0106 - val_accuracy: 0.8990 - val_loss: 0.9908 - learning_rate: 2.5000e-05
# Epoch 130/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8905 - loss: 1.0352
# Epoch 130: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8903 - loss: 1.0355 - val_accuracy: 0.9015 - val_loss: 0.9420 - learning_rate: 2.5000e-05
# Epoch 131/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9060 - loss: 1.0037
# Epoch 131: val_accuracy did not improve from 0.91414
#
# Epoch 131: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9059 - loss: 1.0041 - val_accuracy: 0.9091 - val_loss: 0.9624 - learning_rate: 2.5000e-05
# Epoch 132/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8794 - loss: 1.0526
# Epoch 132: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8794 - loss: 1.0528 - val_accuracy: 0.9066 - val_loss: 0.9425 - learning_rate: 1.2500e-05
# Epoch 133/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8950 - loss: 1.0246
# Epoch 133: val_accuracy did not improve from 0.91414
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8949 - loss: 1.0248 - val_accuracy: 0.9040 - val_loss: 0.9754 - learning_rate: 1.2500e-05
# Epoch 134/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8886 - loss: 1.0266
# Epoch 134: val_accuracy improved from 0.91414 to 0.91919, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8886 - loss: 1.0265 - val_accuracy: 0.9192 - val_loss: 0.9238 - learning_rate: 1.2500e-05
# Epoch 135/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8828 - loss: 1.0459
# Epoch 135: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.8829 - loss: 1.0459 - val_accuracy: 0.9141 - val_loss: 0.9541 - learning_rate: 1.2500e-05
# Epoch 136/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8906 - loss: 1.0264
# Epoch 136: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8906 - loss: 1.0264 - val_accuracy: 0.9167 - val_loss: 0.9327 - learning_rate: 1.2500e-05
# Epoch 137/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8959 - loss: 1.0220
# Epoch 137: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8958 - loss: 1.0220 - val_accuracy: 0.9091 - val_loss: 0.9464 - learning_rate: 1.2500e-05
# Epoch 138/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8981 - loss: 0.9989
# Epoch 138: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8980 - loss: 0.9991 - val_accuracy: 0.9066 - val_loss: 0.9404 - learning_rate: 1.2500e-05
# Epoch 139/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9044 - loss: 0.9737
# Epoch 139: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9042 - loss: 0.9741 - val_accuracy: 0.9141 - val_loss: 0.9220 - learning_rate: 1.2500e-05
# Epoch 140/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8872 - loss: 1.0287
# Epoch 140: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8873 - loss: 1.0287 - val_accuracy: 0.9066 - val_loss: 0.9354 - learning_rate: 1.2500e-05
# Epoch 141/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9008 - loss: 0.9918
# Epoch 141: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9007 - loss: 0.9924 - val_accuracy: 0.8939 - val_loss: 0.9761 - learning_rate: 1.2500e-05
# Epoch 142/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8986 - loss: 0.9981
# Epoch 142: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8985 - loss: 0.9982 - val_accuracy: 0.9141 - val_loss: 0.9068 - learning_rate: 1.2500e-05
# Epoch 143/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8946 - loss: 1.0089
# Epoch 143: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8946 - loss: 1.0091 - val_accuracy: 0.9141 - val_loss: 0.9306 - learning_rate: 1.2500e-05
# Epoch 144/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9067 - loss: 0.9955
# Epoch 144: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9066 - loss: 0.9956 - val_accuracy: 0.9116 - val_loss: 0.9215 - learning_rate: 1.2500e-05
# Epoch 145/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8854 - loss: 1.0106
# Epoch 145: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8855 - loss: 1.0107 - val_accuracy: 0.9167 - val_loss: 0.9202 - learning_rate: 1.2500e-05
# Epoch 146/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8999 - loss: 0.9851
# Epoch 146: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8998 - loss: 0.9853 - val_accuracy: 0.9116 - val_loss: 0.9247 - learning_rate: 1.2500e-05
# Epoch 147/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9024 - loss: 0.9697
# Epoch 147: val_accuracy did not improve from 0.91919
#
# Epoch 147: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9024 - loss: 0.9698 - val_accuracy: 0.9116 - val_loss: 0.9251 - learning_rate: 1.2500e-05
# Epoch 148/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9088 - loss: 0.9898
# Epoch 148: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9086 - loss: 0.9900 - val_accuracy: 0.9141 - val_loss: 0.9172 - learning_rate: 6.2500e-06
# Epoch 149/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9041 - loss: 0.9722
# Epoch 149: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9041 - loss: 0.9723 - val_accuracy: 0.9192 - val_loss: 0.9120 - learning_rate: 6.2500e-06
# Epoch 150/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9070 - loss: 0.9847
# Epoch 150: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9069 - loss: 0.9850 - val_accuracy: 0.9141 - val_loss: 0.9171 - learning_rate: 6.2500e-06
# Epoch 151/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9053 - loss: 0.9899
# Epoch 151: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9051 - loss: 0.9900 - val_accuracy: 0.9141 - val_loss: 0.9083 - learning_rate: 6.2500e-06
# Epoch 152/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8958 - loss: 0.9786
# Epoch 152: val_accuracy did not improve from 0.91919
#
# Epoch 152: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8958 - loss: 0.9787 - val_accuracy: 0.9167 - val_loss: 0.9218 - learning_rate: 6.2500e-06
# Epoch 153/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9034 - loss: 0.9698
# Epoch 153: val_accuracy did not improve from 0.91919
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9032 - loss: 0.9704 - val_accuracy: 0.9192 - val_loss: 0.9109 - learning_rate: 3.1250e-06
# Epoch 154/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8951 - loss: 0.9782
# Epoch 154: val_accuracy improved from 0.91919 to 0.92172, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8952 - loss: 0.9783 - val_accuracy: 0.9217 - val_loss: 0.9086 - learning_rate: 3.1250e-06
# Epoch 155/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9017 - loss: 0.9944
# Epoch 155: val_accuracy improved from 0.92172 to 0.92424, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.9017 - loss: 0.9942 - val_accuracy: 0.9242 - val_loss: 0.9070 - learning_rate: 3.1250e-06
# Epoch 156/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9126 - loss: 0.9697
# Epoch 156: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9125 - loss: 0.9698 - val_accuracy: 0.9167 - val_loss: 0.9061 - learning_rate: 3.1250e-06
# Epoch 157/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8935 - loss: 0.9890
# Epoch 157: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8934 - loss: 0.9890 - val_accuracy: 0.9242 - val_loss: 0.9058 - learning_rate: 3.1250e-06
# Epoch 158/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9103 - loss: 0.9583
# Epoch 158: val_accuracy did not improve from 0.92424
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9102 - loss: 0.9586 - val_accuracy: 0.9242 - val_loss: 0.9048 - learning_rate: 3.1250e-06
# Epoch 159/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9006 - loss: 0.9756
# Epoch 159: val_accuracy improved from 0.92424 to 0.92929, saving model to /content/drive/MyDrive/major_project/models/checkpoint_models/lstm_mixed_best_model.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9006 - loss: 0.9755 - val_accuracy: 0.9293 - val_loss: 0.9002 - learning_rate: 3.1250e-06
# Epoch 160/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9087 - loss: 0.9624
# Epoch 160: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9086 - loss: 0.9625 - val_accuracy: 0.9268 - val_loss: 0.8956 - learning_rate: 3.1250e-06
# Epoch 161/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9016 - loss: 0.9841
# Epoch 161: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9015 - loss: 0.9845 - val_accuracy: 0.9217 - val_loss: 0.9016 - learning_rate: 3.1250e-06
# Epoch 162/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9051 - loss: 0.9607
# Epoch 162: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9050 - loss: 0.9609 - val_accuracy: 0.9192 - val_loss: 0.8969 - learning_rate: 3.1250e-06
# Epoch 163/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9151 - loss: 0.9458
# Epoch 163: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9151 - loss: 0.9460 - val_accuracy: 0.9192 - val_loss: 0.9015 - learning_rate: 3.1250e-06
# Epoch 164/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9097 - loss: 0.9630
# Epoch 164: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.9096 - loss: 0.9632 - val_accuracy: 0.9242 - val_loss: 0.9004 - learning_rate: 3.1250e-06
# Epoch 165/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9007 - loss: 0.9673
# Epoch 165: val_accuracy did not improve from 0.92929
#
# Epoch 165: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9007 - loss: 0.9675 - val_accuracy: 0.9192 - val_loss: 0.9014 - learning_rate: 3.1250e-06
# Epoch 166/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9015 - loss: 0.9876
# Epoch 166: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9014 - loss: 0.9878 - val_accuracy: 0.9268 - val_loss: 0.9007 - learning_rate: 1.5625e-06
# Epoch 167/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8993 - loss: 0.9721
# Epoch 167: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8993 - loss: 0.9722 - val_accuracy: 0.9242 - val_loss: 0.8978 - learning_rate: 1.5625e-06
# Epoch 168/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9131 - loss: 0.9623
# Epoch 168: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9131 - loss: 0.9624 - val_accuracy: 0.9217 - val_loss: 0.9013 - learning_rate: 1.5625e-06
# Epoch 169/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9031 - loss: 0.9658
# Epoch 169: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9030 - loss: 0.9661 - val_accuracy: 0.9217 - val_loss: 0.9014 - learning_rate: 1.5625e-06
# Epoch 170/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9086 - loss: 0.9532
# Epoch 170: val_accuracy did not improve from 0.92929
#
# Epoch 170: ReduceLROnPlateau reducing learning rate to 1e-06.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9085 - loss: 0.9535 - val_accuracy: 0.9217 - val_loss: 0.9036 - learning_rate: 1.5625e-06
# Epoch 171/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9089 - loss: 0.9834
# Epoch 171: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9087 - loss: 0.9835 - val_accuracy: 0.9217 - val_loss: 0.9025 - learning_rate: 1.0000e-06
# Epoch 172/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9077 - loss: 0.9528
# Epoch 172: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9076 - loss: 0.9530 - val_accuracy: 0.9217 - val_loss: 0.9030 - learning_rate: 1.0000e-06
# Epoch 173/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9029 - loss: 0.9737
# Epoch 173: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9029 - loss: 0.9737 - val_accuracy: 0.9217 - val_loss: 0.9027 - learning_rate: 1.0000e-06
# Epoch 174/200
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9039 - loss: 0.9651
# Epoch 174: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9037 - loss: 0.9656 - val_accuracy: 0.9192 - val_loss: 0.9038 - learning_rate: 1.0000e-06
# Epoch 175/200
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9021 - loss: 0.9645
# Epoch 175: val_accuracy did not improve from 0.92929
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9021 - loss: 0.9646 - val_accuracy: 0.9192 - val_loss: 0.9018 - learning_rate: 1.0000e-06
# Epoch 175: early stopping
# Restoring model weights from the end of the best epoch: 160.
#
# Model training complete.
#
# Best Epoch: 159
# Train Accuracy   : 90.01%
# Validation Accuracy: 92.93%
# Train Loss       : 0.9735
# Validation Loss  : 0.9002

# %%
# --- Load Best Model ---
# The best model was saved during training by the ModelCheckpoint callback.
print("\nLoading the best model for final evaluation...")
best_model = models.load_model(
    checkpoint_path,
)

# --- Evaluate ---
print("Evaluating model on the test set...")
loss, accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Loading the best model for final evaluation...
# Evaluating model on the test set...
#
# Test Loss: 0.8819
# Test Accuracy: 93.06%

# %%
# --- Path to save metrics ---
import os
from datetime import datetime

# Set output directory in Google Drive
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
output_dir = f"/content/drive/MyDrive/major_project/metrics/mixed_lstm_training_metrics/Run_{timestamp}"
# /content/drive/MyDrive/major_project/models/checkpoint_models/original_increased_sampled_mixture_augmentation_best_model.keras
os.makedirs(output_dir, exist_ok=True)

# %%
# --- Visualization ---

# 'history', 'best_model', 'X_test', and 'y_test' are already defined.

# ==============================================================================
# IMPORTANT: class names
# ==============================================================================
class_names = [
    'Afternoon', 'Apple', 'April', 'August', 'Banana', 'Day', 'December',
    'Evening', 'February', 'Friday', 'Grapes', 'January', 'July', 'June',
    'March', 'May', 'Monday', 'Morning', 'Night', 'November', 'October',
    'Orange', 'Rainy', 'Saturday', 'September', 'Summer', 'Sunday',
    'Thursday', 'Tuesday', 'Valencia_Orange', 'Watermelon', 'Wednesday', 'Winter'
]


# --- 1. Plot Training History (Accuracy & Loss Curves) ---
print("Displaying model training history...")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle('Model Training History', fontsize=16)

# Accuracy
ax1.plot(history.history['accuracy'], label='Train Accuracy', color='blue', marker='o')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', marker='o')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

# Loss
ax2.plot(history.history['loss'], label='Train Loss', color='blue', marker='o')
ax2.plot(history.history['val_loss'], label='Validation Loss', color='orange', marker='o')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)
plt.savefig(f"{output_dir}/training_history.png", dpi=1000)
plt.show()


# --- 2. Generate Predictions and Detailed Report ---
print("\nGenerating predictions and performance metrics...")
y_pred_probs = best_model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print("\n" + "="*60)
print("           Classification Report")
print("="*60)
report_dict = classification_report(y_true_classes, y_pred_classes,
                                    target_names=class_names, output_dict=True)
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))


# --- 3. Visualize Per-Class Performance ---

# Confusion Matrix
print("\nDisplaying Confusion Matrix...")
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(20, 18))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix', fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig(f"{output_dir}/confusion_matrix.png", dpi=1000)
plt.show()

# F1-Score Bar Chart
print("\nDisplaying F1-Scores for each class...")
report_df = pd.DataFrame(report_dict).transpose()
report_df = report_df.drop(['accuracy', 'macro avg', 'weighted avg'])

plt.figure(figsize=(18, 10))
sns.barplot(data=report_df, x=report_df.index, y='f1-score',
            hue=report_df.index, palette='viridis', legend=False)
plt.title('F1-Score per Class', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(f"{output_dir}/f1_scores.png", dpi=1000)
plt.show()


# --- 4. Display Overall Model Metrics Separately (NEW) ---
print("\n" + "="*60)
print("         Overall Model Performance Summary")
print("="*60)

# Extracting the overall metrics from the report dictionary
overall_accuracy = report_dict['accuracy']
weighted_avg_metrics = report_dict['weighted avg']
overall_precision = weighted_avg_metrics['precision']
overall_recall = weighted_avg_metrics['recall']
overall_f1 = weighted_avg_metrics['f1-score']

print(f"✅ Overall Accuracy:           {overall_accuracy:.4f}")
print(f"🎯 Overall Precision (Weighted): {overall_precision:.4f}")
print(f"🎯 Overall Recall (Weighted):    {overall_recall:.4f}")
print(f"🎯 Overall F1-Score (Weighted):  {overall_f1:.4f}")
print("="*60)
# Out:
# Displaying model training history...
# Generating predictions and performance metrics...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step
#
# ============================================================
#            Classification Report
# ============================================================
#                  precision    recall  f1-score   support
#
#       Afternoon       0.92      1.00      0.96        24
#           Apple       0.92      0.96      0.94        24
#           April       1.00      0.88      0.93        24
#          August       0.92      0.96      0.94        24
#          Banana       1.00      0.92      0.96        24
#             Day       1.00      0.96      0.98        24
#        December       0.88      0.92      0.90        24
#         Evening       0.96      0.96      0.96        24
#        February       0.96      1.00      0.98        24
#          Friday       0.92      0.96      0.94        24
#          Grapes       0.92      0.92      0.92        24
#         January       0.92      0.92      0.92        24
#            July       0.89      1.00      0.94        24
#            June       0.92      0.92      0.92        24
#           March       0.96      0.96      0.96        24
#             May       0.83      1.00      0.91        24
#          Monday       0.89      1.00      0.94        24
#         Morning       1.00      0.96      0.98        24
#           Night       0.95      0.79      0.86        24
#        November       0.86      1.00      0.92        24
#         October       0.74      0.83      0.78        24
#          Orange       1.00      0.88      0.93        24
#           Rainy       1.00      1.00      1.00        24
#        Saturday       1.00      0.79      0.88        24
#       September       0.96      0.96      0.96        24
#          Summer       1.00      0.71      0.83        24
#          Sunday       0.96      0.96      0.96        24
#        Thursday       0.88      0.92      0.90        24
#         Tuesday       0.92      0.92      0.92        24
# Valencia_Orange       1.00      0.92      0.96        24
#      Watermelon       0.88      0.92      0.90        24
#       Wednesday       0.92      1.00      0.96        24
#          Winter       1.00      0.96      0.98        24
#
#        accuracy                           0.93       792
#       macro avg       0.94      0.93      0.93       792
#    weighted avg       0.94      0.93      0.93       792
#
#
# Displaying Confusion Matrix...
# Displaying F1-Scores for each class...
# ============================================================
#          Overall Model Performance Summary
# ============================================================
# ✅ Overall Accuracy:           0.9306
# 🎯 Overall Precision (Weighted): 0.9351
# 🎯 Overall Recall (Weighted):    0.9306
# 🎯 Overall F1-Score (Weighted):  0.9302
# ============================================================

# %%
# --- Save Classification Report to Files ---

# Save the classification report DataFrame to a CSV file for easy spreadsheet access.
report_df.to_csv(f"{output_dir}/classification_report.csv")

# Save the classification report DataFrame to a JSON file for structured data interchange.
report_df.to_json(f"{output_dir}/classification_report.json", indent=4)

# %%
# Create a dictionary to store the overall performance metrics.
# This makes it easy to save these metrics in a structured format like JSON.
overall_metrics = {
    "accuracy": overall_accuracy,
    "precision": overall_precision,
    "recall": overall_recall,
    "f1_score": overall_f1
}

# Save the overall metrics to a JSON file.
# The 'w' mode opens the file for writing, and 'indent=4' makes the JSON file human-readable.
with open(f"{output_dir}/overall_metrics.json", "w") as f:
    import json
    json.dump(overall_metrics, f, indent=4)

# Save the true and predicted labels to NumPy files.
# This allows for more detailed analysis later without needing to re-run the model.
np.save(f"{output_dir}/y_true.npy", y_true_classes)
np.save(f"{output_dir}/y_pred.npy", y_pred_classes)

# %%
# --- Save Final Model for conversion and  Deployment ---

# --- Define Save Path ---
# This saves the final, trained model in the native Keras v3 format.
# This single file contains the architecture, weights, and optimizer state.
final_model_path = "/content/drive/MyDrive/major_project/models/keras_models/lstm_mixed_model.keras"

# --- Save Model ---
print(f"\nSaving the final trained model to: {final_model_path}")
model.save(final_model_path)
print("Model saved successfully.")
print("\nThis file can now be loaded elsewhere for inference or TFLite conversion.")
# Out:
# Saving the final trained model to: /content/drive/MyDrive/major_project/models/keras_models/lstm_mixed_model.keras
# Model saved successfully.
#
# This file can now be loaded elsewhere for inference or TFLite conversion.

# %%
# ------------------------------------------- END OF TRAINING ------------------------

# %%
# ---  Core Paths ---
DRIVE_BASE_PATH = '/content/drive/MyDrive/major_project'

# Input paths
FEATURES_PATH = os.path.join(DRIVE_BASE_PATH, 'features')
KERAS_MODEL_PATH = os.path.join(DRIVE_BASE_PATH, 'models/keras_models/lstm_mixed_model.keras')

# Output paths
TFLITE_MODELS_DIR = os.path.join(DRIVE_BASE_PATH, 'models/tflite_models')
os.makedirs(TFLITE_MODELS_DIR, exist_ok=True) # Ensure the directory exists

MODEL_PATH_TFLITE_STANDARD = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_standard.tflite')
MODEL_PATH_TFLITE_PTQ = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_dynamic.tflite')
MODEL_PATH_TFLITE_PTQ_FULL = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_full.tflite')
MODEL_PATH_TFLITE_PTQ_FULL_FLOAT = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_full_float.tflite')
MODEL_PATH_TFLITE_PTQ_FLOAT16 = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_float16.tflite')

print("\nAll paths configured.")
# Out:
# All paths configured.

# %%
# ==============================================================================
# Load Baseline Keras Model
# ==============================================================================
print(f"Loading baseline Keras model from: {KERAS_MODEL_PATH}")

model_keras = tf.keras.models.load_model(
    KERAS_MODEL_PATH,
)

print("✅ Baseline Keras model loaded successfully.")
model_keras.summary()
# Out:
# Loading baseline Keras model from: /content/drive/MyDrive/major_project/models/keras_models/lstm_mixed_model.keras
# ✅ Baseline Keras model loaded successfully.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 75, 177)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 75, 256)        │       444,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 75, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 33)             │         4,257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,991,013 (7.60 MB)
#  Trainable params: 663,329 (2.53 MB)
#  Non-trainable params: 1,024 (4.00 KB)
#  Optimizer params: 1,326,660 (5.06 MB)

# %%
# ==============================================================================
# Standard TFLite Conversion
# ==============================================================================
print(f"Converting Keras model to standard TFLite format...")

converter = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]
converter.experimental_enable_resource_variables = True
tflite_model_standard = converter.convert()

with open(MODEL_PATH_TFLITE_STANDARD, 'wb') as f:
    f.write(tflite_model_standard)

print(f"✅ Standard TFLite model saved to: {MODEL_PATH_TFLITE_STANDARD}")
# Out:
# Converting Keras model to standard TFLite format...
# Saved artifact at '/tmp/tmp6ohgf6t2'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138742264093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Standard TFLite model saved to: /content/drive/MyDrive/major_project/models/tflite_models/lstm_mixed_model_standard.tflite

# %%
# ==============================================================================
# Post-Training Quantization (Weight Analysis)
# ==============================================================================

import numpy as np

print(f"🔧 Applying Post-Training Quantization...")

# === Print original model precision ===
float_weights = 0
total_weights = 0
for layer in model_keras.layers:
    for weight in layer.get_weights():
        total_weights += weight.size
        if weight.dtype == np.float32:
            float_weights += weight.size

print(f"🔍 Original model precision:")
print(f"   - Total weights: {total_weights}")
print(f"   - Float32 weights: {float_weights} ({(float_weights/total_weights)*100:.2f}%)")
# Out:
# 🔧 Applying Post-Training Quantization...
# 🔍 Original model precision:
#    - Total weights: 664353
#    - Float32 weights: 664353 (100.00%)

# %%
# ------------------------------------------------------------------------------
# Dynamic Range Quantization
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Dynamic Range Quantization...")

converter_dynamic = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_dynamic.optimizations = [tf.lite.Optimize.DEFAULT]

converter_dynamic.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

tflite_model_ptq = converter_dynamic.convert()
with open(MODEL_PATH_TFLITE_PTQ, 'wb') as f:
    f.write(tflite_model_ptq)

print(f"✅ Dynamic Range Quantized model saved at: {MODEL_PATH_TFLITE_PTQ}")
print(f"   → Weights: int8, Activations: float32, Ops: Builtins")
# Out:
# 📦 Converting using Dynamic Range Quantization...
# Saved artifact at '/tmp/tmpi_udefhp'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138742264093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Dynamic Range Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/lstm_mixed_model_ptq_dynamic.tflite
#    → Weights: int8, Activations: float32, Ops: Builtins

# %%
# ------------------------------------------------------------------------------
#  Full Integer Quantization, Inputs/Outputs: int8
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Full Integer Quantization...")

# Define a representative dataset for full integer quantization.
# A small subset of the training data is used for calibration.
# The data needs to be in the format expected by the model's input layer.
def representative_data_gen():
    # Use a small subset of the training data for calibration
    num_calibration_steps = 500  # You can adjust this number
    for i in range(num_calibration_steps):
        # Provide the data with the expected input shape and data type
        yield [X_train[i:i+1].astype(np.float32)]



converter_full = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_full.optimizations = [tf.lite.Optimize.DEFAULT]
converter_full.representative_dataset = representative_data_gen

# # --- FORCE INT8 INPUT AND OUTPUT ---
converter_full.inference_input_type = tf.int8
converter_full.inference_output_type = tf.int8

converter_full.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

tflite_model_full = converter_full.convert()
with open(MODEL_PATH_TFLITE_PTQ_FULL, 'wb') as f:
    f.write(tflite_model_full)

print(f"✅ Full Integer Quantized model saved at: {MODEL_PATH_TFLITE_PTQ_FULL}")
print(f"   → Weights: int8, Activations: int8, Ops: Builtins")
# Out:
# 📦 Converting using Full Integer Quantization...
# Saved artifact at '/tmp/tmpt5gdtjhb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138742264093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ Full Integer Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/lstm_mixed_model_ptq_full.tflite
#    → Weights: int8, Activations: int8, Ops: Builtins

# %%
# ------------------------------------------------------------------------------
#  Full Integer Quantization with Float32 IO/OP
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Full Integer Quantization...")

# Define a representative dataset for full integer quantization.
# A small subset of the training data is used for calibration.
# The data needs to be in the format expected by the model's input layer.
def representative_data_gen():
    # Use a small subset of the training data for calibration
    num_calibration_steps = 500  # You can adjust this number
    for i in range(num_calibration_steps):
        # Provide the data with the expected input shape and data type
        yield [X_train[i:i+1].astype(np.float32)]



converter_full_float = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_full_float.optimizations = [tf.lite.Optimize.DEFAULT]
converter_full_float.representative_dataset = representative_data_gen


converter_full_float.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

tflite_model_full_float = converter_full_float.convert()
with open(MODEL_PATH_TFLITE_PTQ_FULL_FLOAT, 'wb') as f:
    f.write(tflite_model_full_float)

print(f"✅ Full Integer Quantized model saved at: {MODEL_PATH_TFLITE_PTQ_FULL_FLOAT}")
print(f"   → Weights: int8, Activations: int8, Inputs/Outputs: float32, Ops: Builtins")
# Out:
# 📦 Converting using Full Integer Quantization...
# Saved artifact at '/tmp/tmpcj9o09tj'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138742264093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ Full Integer Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/lstm_mixed_model_ptq_full_float.tflite
#    → Weights: int8, Activations: int8, Inputs/Outputs: float32, Ops: Builtins

# %%
# ------------------------------------------------------------------------------
# Float16 quantization
# ------------------------------------------------------------------------------
print(f"\n📦 Converting using Dynamic Range Quantization...")

converter_float16 = tf.lite.TFLiteConverter.from_keras_model(model_keras)
converter_float16.optimizations = [tf.lite.Optimize.DEFAULT]

converter_float16.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]
converter_float16.target_spec.supported_types = [tf.float16]
tflite_model_ptq = converter_float16.convert()
with open(MODEL_PATH_TFLITE_PTQ_FLOAT16, 'wb') as f:
    f.write(tflite_model_ptq)

print(f"✅ Dynamic Range Quantized model saved at: {MODEL_PATH_TFLITE_PTQ_FLOAT16}")
print(f"   → Weights: float16, Activations: float32, Ops: Builtins")
# Out:
# 📦 Converting using Dynamic Range Quantization...
# Saved artifact at '/tmp/tmperi8ihrq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 75, 177), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 33), dtype=tf.float32, name=None)
# Captures:
#   138742264093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264097168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138742264102160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Dynamic Range Quantized model saved at: /content/drive/MyDrive/major_project/models/tflite_models/lstm_mixed_model_ptq_float16.tflite
#    → Weights: float16, Activations: float32, Ops: Builtins

# %%
# ==============================================================================
# Load All Models and Compare Sizes
# ==============================================================================
print("Loading all TFLite models into interpreters for evaluation...")
interpreter_standard = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_STANDARD)
interpreter_standard.allocate_tensors()
interpreter_ptq = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ)
interpreter_ptq.allocate_tensors()
interpreter_full_ptq = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ_FULL)
interpreter_full_ptq.allocate_tensors()
interpreter_full_ptq_float = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ_FULL_FLOAT)
interpreter_full_ptq_float.allocate_tensors()
interpreter_float16 = tf.lite.Interpreter(model_path=MODEL_PATH_TFLITE_PTQ_FLOAT16)
interpreter_float16.allocate_tensors()
print("All models loaded.")

# --- Display Model Sizes ---
size_keras = os.path.getsize(KERAS_MODEL_PATH) / 1024
size_tflite_standard = os.path.getsize(MODEL_PATH_TFLITE_STANDARD) / 1024
size_tflite_ptq = os.path.getsize(MODEL_PATH_TFLITE_PTQ) / 1024
size_tflite_full_ptq = os.path.getsize(MODEL_PATH_TFLITE_PTQ_FULL) / 1024
size_tflite_full_ptq_float = os.path.getsize(MODEL_PATH_TFLITE_PTQ_FULL_FLOAT) / 1024
size_tflite_float16 = os.path.getsize(MODEL_PATH_TFLITE_PTQ_FLOAT16) / 1024


print("\n" + "="*80)
print(f"{'Model Type':<50} | {'Size (KB)':>15}")
print("-"*80)
print(f"{'Original Keras (.keras)':<50} | {size_keras:>15.2f}")
print(f"{'Standard TFLite':<50} | {size_tflite_standard:>15.2f}")
print(f"{'Post-Training Quantized (PTQ)':<50} | {size_tflite_ptq:>15.2f}")
print(f"{'Full Integer Quantized (PTQ)':<50} | {size_tflite_full_ptq:>15.2f}")
print(f"{'Full Integer Quantized (PTQ) Float32 IO/OP':<50} | {size_tflite_full_ptq_float:>15.2f}")
print(f"{'Float16 Quantized TFLite':<50} | {size_tflite_float16:>15.2f}")
print("="*80)
# Out:
# Loading all TFLite models into interpreters for evaluation...
# All models loaded.
#
# ================================================================================
# Model Type                                         |       Size (KB)
# --------------------------------------------------------------------------------
# Original Keras (.keras)                            |         7841.86
# Standard TFLite                                    |         3146.82
# Post-Training Quantized (PTQ)                      |         1254.49
# Full Integer Quantized (PTQ)                       |         3102.05
# Full Integer Quantized (PTQ) Float32 IO/OP         |         3102.37
# Float16 Quantized TFLite                           |         1855.79
# ================================================================================

# %%
# ==============================================================================
# Evaluate All Models on Test Data
# ==============================================================================
def evaluate_tflite_model(interpreter, x_test, y_test):
    input_details, output_details = interpreter.get_input_details()[0], interpreter.get_output_details()[0]
    y_pred, inference_times = [], []

    for sample in tqdm(x_test, desc="Evaluating TFLite Model"):
        sample = np.expand_dims(sample, axis=0).astype(input_details['dtype'])
        interpreter.set_tensor(input_details['index'], sample)
        start_time = time.time()
        interpreter.invoke()
        inference_times.append(time.time() - start_time)
        y_pred.append(np.argmax(interpreter.get_tensor(output_details['index'])))

    return accuracy_score(np.argmax(y_test, axis=1), y_pred), np.mean(inference_times) * 1000

# --- Evaluate Models ---
print("Evaluating models on the test set...")
loss_keras, acc_keras = model_keras.evaluate(X_test, y_test, verbose=0)
# Measure Keras inference time by averaging over 100 predictions
time_keras = np.mean([timeit.timeit(lambda: model_keras.predict(np.expand_dims(X_test[i], axis=0), verbose=0), number=1) for i in range(100)]) * 1000

acc_standard, time_standard = evaluate_tflite_model(interpreter_standard, X_test, y_test)
acc_ptq, time_ptq = evaluate_tflite_model(interpreter_ptq, X_test, y_test)
acc_full_ptq, time_full_ptq = evaluate_tflite_model(interpreter_full_ptq, X_test, y_test)
acc_full_ptq_float, time_full_ptq_float = evaluate_tflite_model(interpreter_full_ptq_float, X_test, y_test)
acc_float16, time_float16 = evaluate_tflite_model(interpreter_float16, X_test, y_test)


# --- Display Results ---
results_df = pd.DataFrame({
    "Model Type": ["Original Keras", "Standard TFLite", "Dynamic PTQ TFLite", "Full Integer PTQ TFLite", "Full Integer PTQ (Float IO)", "Float16 PTQ TFLite"],
    "Accuracy": [f"{acc_keras:.4f}", f"{acc_standard:.4f}", f"{acc_ptq:.4f}", f"{acc_full_ptq:.4f}", f"{acc_full_ptq_float:.4f}", f"{acc_float16:.4f}"],
    "Avg Inference Time (ms)": [f"{time_keras:.4f}", f"{time_standard:.4f}", f"{time_ptq:.4f}", f"{time_full_ptq:.4f}", f"{time_full_ptq_float:.4f}", f"{time_float16:.4f}"]
})

print("\n\n" + "="*65)
print("          Model Performance on Test Set        ")
print("="*65)
print(results_df.to_string(index=False))
print("="*65)
# Out:
# Evaluating models on the test set...
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# Evaluating TFLite Model:   0%|          | 0/792 [00:00<?, ?it/s]
# =================================================================
#           Model Performance on Test Set
# =================================================================
#                  Model Type Accuracy Avg Inference Time (ms)
#              Original Keras   0.9255                500.9877
#             Standard TFLite   0.9255                 18.4376
#          Dynamic PTQ TFLite   0.9255                  7.3609
#     Full Integer PTQ TFLite   0.0278                  6.0198
# Full Integer PTQ (Float IO)   0.8106                  5.9124
#          Float16 PTQ TFLite   0.9255                 19.0830
# =================================================================

# %%
import pprint

# ==============================================================================
# pretty print dtype
# ==============================================================================
models = {
    "Standard Float32": MODEL_PATH_TFLITE_STANDARD,
    "Dynamic PTQ": MODEL_PATH_TFLITE_PTQ,
    "Full Integer PTQ": MODEL_PATH_TFLITE_PTQ_FULL,
    "Full Integer w/Float I/O": MODEL_PATH_TFLITE_PTQ_FULL_FLOAT,
    "Float16 PTQ": MODEL_PATH_TFLITE_PTQ_FLOAT16
}

summary = {}

for label, path in models.items():
    interpreter = tf.lite.Interpreter(model_path=path)
    interpreter.allocate_tensors()

    # Input/output types
    inp = interpreter.get_input_details()[0]
    out = interpreter.get_output_details()[0]
    io_dtype = (inp['dtype'], out['dtype'])

    # Tensor details
    details = interpreter.get_tensor_details()
    weights_dtype = set()
    bias_dtype = set()
    act_quantized = False

    for td in details:
        name = td['name'].lower()
        dtype = td['dtype']
        qpar = td.get('quantization_parameters', {})
        scales = qpar.get('scales', None)
        has_q = scales is not None and len(scales) > 0

        if 'kernel' in name or 'weight' in name:
            weights_dtype.add(dtype)
        if 'bias' in name:
            bias_dtype.add(dtype)
        if has_q and not ('bias' in name):
            act_quantized = True

    summary[label] = {
        "Weights dtype": list(weights_dtype),
        "Activations quantized": act_quantized,
        "Bias dtype": list(bias_dtype),
        "Input/Output dtype": io_dtype
    }

pprint.pprint(summary, sort_dicts=False, indent=2)
# Out:
# { 'Standard Float32': { 'Weights dtype': [],
#                         'Activations quantized': False,
#                         'Bias dtype': [<class 'numpy.float32'>],
#                         'Input/Output dtype': ( <class 'numpy.float32'>,
#                                                 <class 'numpy.float32'>)},
#   'Dynamic PTQ': { 'Weights dtype': [],
#                    'Activations quantized': True,
#                    'Bias dtype': [<class 'numpy.float32'>],
#                    'Input/Output dtype': ( <class 'numpy.float32'>,
#                                            <class 'numpy.float32'>)},
#   'Full Integer PTQ': { 'Weights dtype': [],
#                         'Activations quantized': True,
#                         'Bias dtype': [<class 'numpy.int8'>],
#                         'Input/Output dtype': ( <class 'numpy.int8'>,
#                                                 <class 'numpy.int8'>)},
#   'Full Integer w/Float I/O': { 'Weights dtype': [],
#                                 'Activations quantized': True,
#                                 'Bias dtype': [<class 'numpy.int8'>],
#                                 'Input/Output dtype': ( <class 'numpy.float32'>,
#                                                         <class 'numpy.float32'>)},
#   'Float16 PTQ': { 'Weights dtype': [],
#                    'Activations quantized': False,
#                    'Bias dtype': [<class 'numpy.float32'>],
#                    'Input/Output dtype': ( <class 'numpy.float32'>,
#                                            <class 'numpy.float32'>)}}

# %%
# ==============================================================================
# quantization reference
# ==============================================================================
# https://ai.google.dev/edge/litert/models/post_training_quantization

# %%
from tabulate import tabulate
# ==============================================================================
# tabulate dtype
# ==============================================================================
MODEL_PATH_TFLITE_STANDARD = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_standard.tflite')
MODEL_PATH_TFLITE_PTQ = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_dynamic.tflite')
MODEL_PATH_TFLITE_PTQ_FULL = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_full.tflite')
MODEL_PATH_TFLITE_PTQ_FULL_FLOAT = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_full_float.tflite')
MODEL_PATH_TFLITE_PTQ_FLOAT16 = os.path.join(TFLITE_MODELS_DIR, 'lstm_mixed_model_ptq_float16.tflite')

models_tflite = {
    "Standard Float32": MODEL_PATH_TFLITE_STANDARD,
    "Dynamic PTQ": MODEL_PATH_TFLITE_PTQ,
    "Full Integer PTQ": MODEL_PATH_TFLITE_PTQ_FULL,
    "Full Integer w/Float I/O": MODEL_PATH_TFLITE_PTQ_FULL_FLOAT,
    "Float16 PTQ": MODEL_PATH_TFLITE_PTQ_FLOAT16
}

table_data = []

# Analyze Keras model
try:
    keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH)
    weights = keras_model.weights
    weight_dtypes = set()
    bias_dtypes = set()

    for w in weights:
        name = w.name.lower()
        dtype = str(w.dtype)
        if 'bias' in name:
            bias_dtypes.add(dtype)
        else:
            weight_dtypes.add(dtype)

    try:
        input_dtype = keras_model.input.dtype.name
        output_dtype = keras_model.output.dtype.name
    except Exception:
        input_dtype = output_dtype = "n/a"

    table_data.append([
        "Keras Model",
        ', '.join(weight_dtypes) if weight_dtypes else "n/a",
        "Float",  # Keras models are float by default
        ', '.join(bias_dtypes) if bias_dtypes else "n/a",
        f"{input_dtype} → {output_dtype}"
    ])
except Exception as e:
    print("❌ Error loading Keras model:", e)
    table_data.append(["Keras Model", "n/a", "n/a", "n/a", "n/a"])

# Analyze TFLite models
for label, path in models_tflite.items():
    try:
        interpreter = tf.lite.Interpreter(model_path=path)
        interpreter.allocate_tensors()

        # Input/Output types
        try:
            inp = interpreter.get_input_details()[0]
            out = interpreter.get_output_details()[0]
            io_dtype = f"{inp['dtype'].__name__} → {out['dtype'].__name__}"
        except Exception:
            io_dtype = "n/a"

        # Tensor details
        details = interpreter.get_tensor_details()
        weights_dtype = set()
        bias_dtype = set()
        act_quantized = False

        for td in details:
            name = td.get('name', '').lower()
            dtype = td.get('dtype', None)
            if dtype is not None:
                dtype_name = dtype.__name__
            else:
                dtype_name = "n/a"

            qpar = td.get('quantization_parameters', {})
            scales = qpar.get('scales', [])
            has_q = scales is not None and len(scales) > 0

            if 'kernel' in name or 'weight' in name:
                weights_dtype.add(dtype_name)
            elif 'bias' in name:
                bias_dtype.add(dtype_name)
            if has_q and 'bias' not in name:
                act_quantized = True

        table_data.append([
            label,
            ', '.join(weights_dtype) if weights_dtype else "n/a",
            "Quantized" if act_quantized else "Float",
            ', '.join(bias_dtype) if bias_dtype else "n/a",
            io_dtype
        ])
    except Exception as e:
        print(f"❌ Error processing {label} model:", e)
        table_data.append([label, "n/a", "n/a", "n/a", "n/a"])

# Print the final table
headers = ["Conversion Type", "Weights", "Activations", "Bias", "Input/Output"]
print(tabulate(table_data, headers=headers, tablefmt="grid"))
# Out:
# +--------------------------+-----------+---------------+---------+-------------------+
# | Conversion Type          | Weights   | Activations   | Bias    | Input/Output      |
# +==========================+===========+===============+=========+===================+
# | Keras Model              | float32   | Float         | float32 | n/a → n/a         |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Standard Float32         | n/a       | Float         | float32 | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Dynamic PTQ              | n/a       | Quantized     | float32 | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Full Integer PTQ         | n/a       | Quantized     | int8    | int8 → int8       |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Full Integer w/Float I/O | n/a       | Quantized     | int8    | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
# | Float16 PTQ              | n/a       | Float         | float32 | float32 → float32 |
# +--------------------------+-----------+---------------+---------+-------------------+
